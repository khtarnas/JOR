# %%
from sqlalchemy import create_engine, MetaData, Table
import json
import pandas as pd

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
db_url = "mysql+pymysql://maint:strangle.explode.sprout.underfeed.yo-yo@cmlpsiturk.compmemlab.org:3306/psiturk"
table_name = "JOR"

# %%
data_column_name = 'datastring'

# boilerplace sqlalchemy setup
engine = create_engine(db_url)
metadata = MetaData()
metadata.bind = engine
table = Table(table_name, metadata, autoload=True)

# make a query and loop through
s = table.select()

# %%
rows = s.execute()

# %% [raw]
# # Status codes
# NOT_ACCEPTED = 0
# ALLOCATED = 1
# STARTED = 2
# COMPLETED = 3
# SUBMITTED = 4
# CREDITED = 5
# QUITEARLY = 6
# BONUSED = 7

# %%
data = []

#status codes of subjects who completed experiment
statuses = [3,4,5,7]
# statuses=[0,1,2,3,4,5,6,7]

# if you have workers you wish to exclude, add them here
exclude = [] 

conditions = []
version = '2.1.1'

for row in rows:
    # only use subjects who completed experiment and aren't excluded
    if (row['status'] in statuses) and (row['uniqueid'] not in exclude) and (row['codeversion'] == version):
        conditions.append({
                'uniqueid': row['uniqueid'],
                'beginhit': row['beginhit'],
                'endhit': row['endhit'],
                'status': row['status'],
                'counterbalance': row['counterbalance'],
                'workerid': row['workerid'],
                'codeversion': row['codeversion']
            })
        data.append(row[data_column_name])

# %%
condition_frame = pd.DataFrame(conditions)
condition_frame.sort_values('beginhit')
# Out:
#                                           uniqueid            beginhit  \
# 133  A206WLS4KMBH86:3EKVH9QMEZB5BYPK0XRDUQX9TJL2DT 2022-09-28 15:23:46
# 149  A24MI8I7ZUS3HQ:3TXWC2NHN0XMD7T1IW1HZCRN0S4S94 2022-09-28 15:24:09
# 73   A1HSEVGZBWJUPH:3VHP9MDGRORF70VIOWB9U39GHNDFCP 2022-09-28 15:24:41
# 278  A3D4ZHM3ABM5Z3:3G5W44VEU8P34Y31RTYP07M0NBMKG6 2022-09-28 15:25:45
# 59   A1F8F956ETH1TA:3YMU66OBIOFC282TL8VSNF68VUIHGZ 2022-09-28 15:27:40
# ..                                             ...                 ...
# 66   A1GEO1VUUQQ9K2:3COPXFW7XCJ9HBW0UCOCUG0SQPMPK4 2022-10-17 16:12:18
# 321  A3UE8ANAIM7F15:3YT88D1N0952AMRDWER5HDXRLU33KH 2022-10-17 16:33:01
# 182  A2G2T6EMXAOKMS:3S06PH7KSSBYMD7OHTRZP7N432O1D8 2022-10-17 19:10:51
# 377   AKE4AYF86KJVU:37C0GNLMHGATTZ8LNZ3GK3ELBD5D6J 2022-10-17 19:20:40
# 174  A2DQ0OE2TBY9E0:36AHBNMV1SJVCJIRTIY83UYEAN2DYN 2022-10-17 19:34:45
#
#                  endhit  status  counterbalance        workerid codeversion
# 133 2022-09-28 15:51:02       4               3  A206WLS4KMBH86       2.1.1
# 149 2022-09-28 16:57:42       4              93  A24MI8I7ZUS3HQ       2.1.1
# 73  2022-09-28 15:59:26       4              81  A1HSEVGZBWJUPH       2.1.1
# 278 2022-09-28 15:42:40       4              80  A3D4ZHM3ABM5Z3       2.1.1
# 59  2022-09-28 15:55:11       4              12  A1F8F956ETH1TA       2.1.1
# ..                  ...     ...             ...             ...         ...
# 66  2022-10-17 16:32:04       4               3  A1GEO1VUUQQ9K2       2.1.1
# 321 2022-10-17 17:15:47       4               8  A3UE8ANAIM7F15       2.1.1
# 182 2022-10-17 19:39:53       4              54  A2G2T6EMXAOKMS       2.1.1
# 377 2022-10-17 21:00:44       4              86   AKE4AYF86KJVU       2.1.1
# 174 2022-10-17 20:06:12       4              24  A2DQ0OE2TBY9E0       2.1.1
#
# [428 rows x 7 columns]

# %%
condition_frame['uniqueid']
# Out:
# 0      A102WSFN62OS6I:3BWI6RSP7HGHP50Q24JSWZW2591E74
# 1      A1122EUMFXHF38:3KB8R4ZV1FE2BVZ7LGLW143A17IBGZ
# 2      A116QUKBGZ6DLC:37M28K1J0RK7JNKGN86336BKBHBJAD
# 3       A1198W1SPF1R4:3QEMNNSB2Y6CXZMQ6988QHEH5P9D73
# 4      A121YWZJNUUZRJ:3IXQG4FA2U5NWLCZ7AFM9NHNXUNB98
#                            ...
# 423     AXGQ4AW54L9TM:3L70J4KAZHTUG1KODCKS08G76XEADQ
# 424     AXVGIRLNPA6Z2:3R2UR8A0IBNXGBJ6EVQMVA34B4MXOM
# 425     AXYNQIL0J2BP2:3M81GAB8A1QTOKTLOCQ8VI7C7UPQB7
# 426     AY7M9MOLNXIIK:3CPLWGV3MP6PXU1WA0KV0IHHERZ9N9
# 427     AZXNPVVLWKK1V:3RRCEFRB7NJMZF6NQFJVSF67B29B4C
# Name: uniqueid, Length: 428, dtype: object

# %%
# Now we have all participant datastrings in a list.
# Let's make it a bit easier to work with:

# parse each participant's datastring as json object
# and take the 'data' sub-object
subject_data = []
for subject_json in data:
    try:
        subject_dict = json.loads(subject_json)
        subject_data.append(subject_dict['data'])
    except:
        continue

# %%
# insert uniqueid field into trialdata in case it wasn't added
# in experiment:
for part in subject_data:
    for record in part:
        record['trialdata']['uniqueid'] = record['uniqueid']

# %%
# flatten nested list so we just have a list of the trialdata recorded
# each time psiturk.recordTrialData(trialdata) was called.
trialdata = []
for part in subject_data:
    for record in part:
        trialdata.append(record['trialdata'])

# %%
# Put all subjects' trial data into a dataframe object from the
# 'pandas' python library: one option among many for analysis
data_frame = pd.DataFrame(trialdata)

# Print how many subj before eliminations:
print("Subjects before eliminations: ", len(data_frame['uniqueid'].unique()))
# Out:
# Subjects before eliminations:  428

# %%
# Remove subjects that admitted to writing down studied words
were_distracted = 0
took_notes = 0
both = 0

for i in data_frame['uniqueid'].unique():
    df = data_frame[data_frame['uniqueid'] == i]
    
    # get whether or not indicated distracted / wrote notes
    distracted = (df['responses'].str.startswith("{\"distracted\":\"Yes\"}", na=False) == True).sum()
    wrote_notes = (df['responses'].str.startswith("{\"wrote_notes\":\"Yes\"}", na=False) == True).sum()
    
    # increment counters appropriately
    if distracted and wrote_notes:
        both += 1
        data_frame = data_frame.drop(df.index)
    elif distracted:
        were_distracted += 1
        data_frame = data_frame.drop(df.index)
    elif wrote_notes:
        took_notes += 1
        data_frame = data_frame.drop(df.index)
    
print("individuals distracted, but did not take notes: ", were_distracted)
print("Individuals who took notes, but were not distracted: ", took_notes)
print("Individuals who did both: ", both)

# Print how many subj after eliminations
print("Subjects remaining: ", len(data_frame['uniqueid'].unique()))
# Out:
# individuals distracted, but did not take notes:  5
# Individuals who took notes, but were not distracted:  35
# Individuals who did both:  17
# Subjects remaining:  371

# %%
def getComparisonAccuracy(df, comp1, comp2):
    left_correct = len(df[df['left_comp_type'] == comp1][df['right_comp_type'] == comp2][df['chosen_side'] == df['correct_side']])
    right_correct = len(df[df['left_comp_type'] == comp2][df['right_comp_type'] == comp1][df['chosen_side'] == df['correct_side']])
    left = len(df[df['left_comp_type'] == comp1][df['right_comp_type'] == comp2])
    right = len(df[df['left_comp_type'] == comp2][df['right_comp_type'] == comp1])
    return (left_correct + right_correct)/(left + right)

def getFirstDistanceAccuracy(df, dist):
    second_distances = [6, 8, 10, 16, 22, 30, 40]
    total = 0
    num = 0
    for i in second_distances:
        if (i > dist):
            total += getComparisonAccuracy(df, dist, i)
            num += 1
    return total / num

def getSecondDistanceAccuracy(df, dist):
    first_distances = [4, 6, 8, 10, 14, 18, 22, 28, 34]
    total = 0
    num = 0
    for i in first_distances:
        if (i < dist):
            total += getComparisonAccuracy(df, dist, i)
            num += 1
    return total / num

def getOverallAccuracy(df):
    first_distances = [4, 6, 8, 10, 14, 18, 22, 28, 34]
    total = 0
    for i in first_distances:
        total += getFirstDistanceAccuracy(df, i)
    return total / len(first_distances)

# %%
data_frame_2_1_1 = data_frame
data_frame
# Out:
#               rt                                   responses  type  \
# 0        14959.0                             {"name":"Maia"}  NAME
# 1         3699.0                                         NaN   NaN
# 2       129585.0                                         NaN   NaN
# 3        48232.0                                         NaN   NaN
# 4         8246.0                                         NaN   NaN
# ...          ...                                         ...   ...
# 115642    3473.6           {"education":"Bachelor's degree"}   NaN
# 115643    3677.5  {"marital":"Married/Domestic Partnership"}   NaN
# 115644    4424.2                        {"wrote_notes":"No"}   NaN
# 115645    4674.8                         {"distracted":"No"}   NaN
# 115646    6201.9                                         NaN   NaN
#
#                     trial_type  trial_index  time_elapsed internal_node_id  \
# 0             survey-html-form            0         14980      0.0-0.0-0.0
# 1       html-keyboard-response            1         18918          0.0-1.0
# 2       html-keyboard-response            2        148741          0.0-2.0
# 3         html-button-response            3        197192          0.0-3.0
# 4         html-button-response            4        205459      0.0-5.0-0.0
# ...                        ...          ...           ...              ...
# 115642         survey-dropdown          274       1166195        0.0-255.0
# 115643         survey-dropdown          275       1169877        0.0-256.0
# 115644     survey-multi-choice          276       1174308        0.0-257.0
# 115645     survey-multi-choice          277       1178988        0.0-258.0
# 115646    html-button-response          278       1185195        0.0-259.0
#
#                                              uniqueid  \
# 0       A102WSFN62OS6I:3BWI6RSP7HGHP50Q24JSWZW2591E74
# 1       A102WSFN62OS6I:3BWI6RSP7HGHP50Q24JSWZW2591E74
# 2       A102WSFN62OS6I:3BWI6RSP7HGHP50Q24JSWZW2591E74
# 3       A102WSFN62OS6I:3BWI6RSP7HGHP50Q24JSWZW2591E74
# 4       A102WSFN62OS6I:3BWI6RSP7HGHP50Q24JSWZW2591E74
# ...                                               ...
# 115642   AZXNPVVLWKK1V:3RRCEFRB7NJMZF6NQFJVSF67B29B4C
# 115643   AZXNPVVLWKK1V:3RRCEFRB7NJMZF6NQFJVSF67B29B4C
# 115644   AZXNPVVLWKK1V:3RRCEFRB7NJMZF6NQFJVSF67B29B4C
# 115645   AZXNPVVLWKK1V:3RRCEFRB7NJMZF6NQFJVSF67B29B4C
# 115646   AZXNPVVLWKK1V:3RRCEFRB7NJMZF6NQFJVSF67B29B4C
#
#                                                  stimulus key_press  ...  \
# 0                                                     NaN       NaN  ...
# 1       Welcome to the <strong>Judgment of Recency</st...            ...
# 2       <p>In this experiment, you will encounter a nu...            ...
# 3       <p style = 'text-align:left;'>Dear Participant...       NaN  ...
# 4       <p class='inst-justified'>According to Wikiped...       NaN  ...
# ...                                                   ...       ...  ...
# 115642                                                NaN       NaN  ...
# 115643                                                NaN       NaN  ...
# 115644                                                NaN       NaN  ...
# 115645                                                NaN       NaN  ...
# 115646  <div style="text-align:center;">Congratulation...       NaN  ...
#
#        left_word_test right_word_test  chosen_side comparison_type  \
# 0                 NaN             NaN          NaN             NaN
# 1                 NaN             NaN          NaN             NaN
# 2                 NaN             NaN          NaN             NaN
# 3                 NaN             NaN          NaN             NaN
# 4                 NaN             NaN          NaN             NaN
# ...               ...             ...          ...             ...
# 115642            NaN             NaN          NaN             NaN
# 115643            NaN             NaN          NaN             NaN
# 115644            NaN             NaN          NaN             NaN
# 115645            NaN             NaN          NaN             NaN
# 115646            NaN             NaN          NaN             NaN
#
#        left_comp_type right_comp_type correct_side question_order  required  \
# 0                 NaN             NaN          NaN            NaN       NaN
# 1                 NaN             NaN          NaN            NaN       NaN
# 2                 NaN             NaN          NaN            NaN       NaN
# 3                 NaN             NaN          NaN            NaN       NaN
# 4                 NaN             NaN          NaN            NaN       NaN
# ...               ...             ...          ...            ...       ...
# 115642            NaN             NaN          NaN            [0]       NaN
# 115643            NaN             NaN          NaN            [0]       NaN
# 115644            NaN             NaN          NaN            [0]       NaN
# 115645            NaN             NaN          NaN            [0]       NaN
# 115646            NaN             NaN          NaN            NaN      True
#
#        further_experiments
# 0                      NaN
# 1                      NaN
# 2                      NaN
# 3                      NaN
# 4                      NaN
# ...                    ...
# 115642                 NaN
# 115643                 NaN
# 115644                 NaN
# 115645                 NaN
# 115646                 yes
#
# [100180 rows x 26 columns]

# %%
accuracies = []
for i in data_frame_2_1_1['uniqueid'].unique():
    df = data_frame_2_1_1[data_frame_2_1_1['uniqueid'] == i]
    accuracies.append(getOverallAccuracy(df))

# %%
criteria_count = 0
for i in data_frame_2_1_1['uniqueid'].unique():
    
    df = data_frame_2_1_1[data_frame_2_1_1['uniqueid'] == i]
    if (getOverallAccuracy(df) < 0.6):
        data_frame_2_1_1 = data_frame_2_1_1.drop(df.index)
        criteria_count += 1

print("Subject who did not make the criteria: ", criteria_count)

# Print how many subj after eliminations
print("Subjects remaining: ", len(data_frame_2_1_1['uniqueid'].unique()))
# Out:
# Subject who did not make the criteria:  277
# Subjects remaining:  94

# %%
# %store data_frame_2_1_1
# Out:
# Stored 'data_frame_2_1_1' (DataFrame)

# %%
data_frame_2_1_1
# Out:
#               rt                                   responses  type  \
# 0        14959.0                             {"name":"Maia"}  NAME
# 1         3699.0                                         NaN   NaN
# 2       129585.0                                         NaN   NaN
# 3        48232.0                                         NaN   NaN
# 4         8246.0                                         NaN   NaN
# ...          ...                                         ...   ...
# 113210    6860.0           {"education":"Bachelor's degree"}   NaN
# 113211    7242.0  {"marital":"Married/Domestic Partnership"}   NaN
# 113212   10523.0                        {"wrote_notes":"No"}   NaN
# 113213    7468.0                         {"distracted":"No"}   NaN
# 113214    6901.0                                         NaN   NaN
#
#                     trial_type  trial_index  time_elapsed internal_node_id  \
# 0             survey-html-form            0         14980      0.0-0.0-0.0
# 1       html-keyboard-response            1         18918          0.0-1.0
# 2       html-keyboard-response            2        148741          0.0-2.0
# 3         html-button-response            3        197192          0.0-3.0
# 4         html-button-response            4        205459      0.0-5.0-0.0
# ...                        ...          ...           ...              ...
# 113210         survey-dropdown          263       3975366        0.0-255.0
# 113211         survey-dropdown          264       3982614        0.0-256.0
# 113212     survey-multi-choice          265       3993144        0.0-257.0
# 113213     survey-multi-choice          266       4000616        0.0-258.0
# 113214    html-button-response          267       4007527        0.0-259.0
#
#                                              uniqueid  \
# 0       A102WSFN62OS6I:3BWI6RSP7HGHP50Q24JSWZW2591E74
# 1       A102WSFN62OS6I:3BWI6RSP7HGHP50Q24JSWZW2591E74
# 2       A102WSFN62OS6I:3BWI6RSP7HGHP50Q24JSWZW2591E74
# 3       A102WSFN62OS6I:3BWI6RSP7HGHP50Q24JSWZW2591E74
# 4       A102WSFN62OS6I:3BWI6RSP7HGHP50Q24JSWZW2591E74
# ...                                               ...
# 113210   AWJKR5GA7BS7V:3L0KT67Y8FN1E819Q8TXYTKEBZEYSM
# 113211   AWJKR5GA7BS7V:3L0KT67Y8FN1E819Q8TXYTKEBZEYSM
# 113212   AWJKR5GA7BS7V:3L0KT67Y8FN1E819Q8TXYTKEBZEYSM
# 113213   AWJKR5GA7BS7V:3L0KT67Y8FN1E819Q8TXYTKEBZEYSM
# 113214   AWJKR5GA7BS7V:3L0KT67Y8FN1E819Q8TXYTKEBZEYSM
#
#                                                  stimulus key_press  ...  \
# 0                                                     NaN       NaN  ...
# 1       Welcome to the <strong>Judgment of Recency</st...            ...
# 2       <p>In this experiment, you will encounter a nu...            ...
# 3       <p style = 'text-align:left;'>Dear Participant...       NaN  ...
# 4       <p class='inst-justified'>According to Wikiped...       NaN  ...
# ...                                                   ...       ...  ...
# 113210                                                NaN       NaN  ...
# 113211                                                NaN       NaN  ...
# 113212                                                NaN       NaN  ...
# 113213                                                NaN       NaN  ...
# 113214  <div style="text-align:center;">Congratulation...       NaN  ...
#
#        left_word_test right_word_test  chosen_side comparison_type  \
# 0                 NaN             NaN          NaN             NaN
# 1                 NaN             NaN          NaN             NaN
# 2                 NaN             NaN          NaN             NaN
# 3                 NaN             NaN          NaN             NaN
# 4                 NaN             NaN          NaN             NaN
# ...               ...             ...          ...             ...
# 113210            NaN             NaN          NaN             NaN
# 113211            NaN             NaN          NaN             NaN
# 113212            NaN             NaN          NaN             NaN
# 113213            NaN             NaN          NaN             NaN
# 113214            NaN             NaN          NaN             NaN
#
#        left_comp_type right_comp_type correct_side question_order  required  \
# 0                 NaN             NaN          NaN            NaN       NaN
# 1                 NaN             NaN          NaN            NaN       NaN
# 2                 NaN             NaN          NaN            NaN       NaN
# 3                 NaN             NaN          NaN            NaN       NaN
# 4                 NaN             NaN          NaN            NaN       NaN
# ...               ...             ...          ...            ...       ...
# 113210            NaN             NaN          NaN            [0]       NaN
# 113211            NaN             NaN          NaN            [0]       NaN
# 113212            NaN             NaN          NaN            [0]       NaN
# 113213            NaN             NaN          NaN            [0]       NaN
# 113214            NaN             NaN          NaN            NaN      True
#
#        further_experiments
# 0                      NaN
# 1                      NaN
# 2                      NaN
# 3                      NaN
# 4                      NaN
# ...                    ...
# 113210                 NaN
# 113211                 NaN
# 113212                 NaN
# 113213                 NaN
# 113214                 yes
#
# [25345 rows x 26 columns]

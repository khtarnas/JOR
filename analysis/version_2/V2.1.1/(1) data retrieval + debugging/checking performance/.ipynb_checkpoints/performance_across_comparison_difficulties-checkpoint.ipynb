# %%
# Imports
import random
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import math

# %%
# remove warnings
import warnings
warnings.filterwarnings("ignore")

# %%
# Get raw 2.1.1 data
# %store -r data_frame_2_1_1_preexclusions
data_frame = data_frame_2_1_1_preexclusions

# %%
# Clarify dataframe
study_test_df = data_frame.query('block_number > 0 and trial_period == trial_period')
test_df = study_test_df.query('trial_period == "test"')
test_df['correct'] = test_df['correct_side'] == test_df['chosen_side']
test_df['more_recent_probe'] = test_df[['left_comp_type', 'right_comp_type']].min(axis=1)
test_df['less_recent_probe'] = test_df[['left_comp_type', 'right_comp_type']].max(axis=1)
df = test_df

# %%
# Get comparisons and overall accuracies in comparable form
# sort values: https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.sort_values.html
correct_by_comparison = df.groupby(['more_recent_probe', 'less_recent_probe']).agg({'correct': 'mean'}).reset_index()
correct_by_comparison['comparison'] = '(' + correct_by_comparison['more_recent_probe'].astype(str) + ', ' + correct_by_comparison['less_recent_probe'].astype(str) + ')'
correct_by_comparison = correct_by_comparison.sort_values(by=['correct'])

# Graph
fig = sns.catplot(x='comparison', y='correct', data=correct_by_comparison, kind='point', height=8, aspect=34/8)
fig.set(xlabel='Comparison Type (more recent probe, less recent probe)', ylabel='Accuracy')

# %%
correct_by_comparison['comparison'].to_numpy()
# Out:
# array(['(28.0, 30.0)', '(14.0, 22.0)', '(10.0, 16.0)', '(34.0, 40.0)',
#        '(22.0, 30.0)', '(6.0, 8.0)', '(28.0, 40.0)', '(4.0, 8.0)',
#        '(18.0, 30.0)', '(14.0, 40.0)', '(18.0, 22.0)', '(6.0, 10.0)',
#        '(8.0, 10.0)', '(8.0, 22.0)', '(14.0, 16.0)', '(4.0, 10.0)',
#        '(18.0, 40.0)', '(4.0, 6.0)', '(8.0, 16.0)', '(10.0, 40.0)',
#        '(6.0, 22.0)', '(10.0, 22.0)', '(6.0, 16.0)', '(6.0, 30.0)',
#        '(22.0, 40.0)', '(14.0, 30.0)', '(4.0, 22.0)', '(6.0, 40.0)',
#        '(4.0, 16.0)', '(10.0, 30.0)', '(8.0, 40.0)', '(4.0, 30.0)',
#        '(8.0, 30.0)', '(4.0, 40.0)'], dtype=object)

# %%
# Get amount correct by subject and comparison type
correct_by_subj_and_comparison = df
correct_by_subj_and_comparison['comparison'] = '(' + correct_by_subj_and_comparison['more_recent_probe'].astype(str) + ', ' + correct_by_subj_and_comparison['less_recent_probe'].astype(str) + ')'
correct_by_subj_and_comparison = correct_by_subj_and_comparison.groupby(['uniqueid', 'comparison']).agg({'correct': 'sum'}).reset_index()

# correct_by_subj_and_comparison['performance_difference'] = correct_by_subj_and_comparison.groupby('uniqueid').apply(lambda x: 
# correct_by_subj_and_comparison['newcolumn'] = df.groupby('uniqueid').apply(lambda x: fxy(x['A'], x['B']), axis=1)

# correct_by_subj_and_comparison = df.groupby('uniqueid').agg({'correct': 'mean'}).reset_index()
# correct_by_subj_and_comparison
# Out:
#                                             uniqueid    comparison  correct
# 0      A102WSFN62OS6I:3BWI6RSP7HGHP50Q24JSWZW2591E74  (10.0, 16.0)        2
# 1      A102WSFN62OS6I:3BWI6RSP7HGHP50Q24JSWZW2591E74  (10.0, 22.0)        2
# 2      A102WSFN62OS6I:3BWI6RSP7HGHP50Q24JSWZW2591E74  (10.0, 30.0)        1
# 3      A102WSFN62OS6I:3BWI6RSP7HGHP50Q24JSWZW2591E74  (10.0, 40.0)        3
# 4      A102WSFN62OS6I:3BWI6RSP7HGHP50Q24JSWZW2591E74  (14.0, 16.0)        0
# ...                                              ...           ...      ...
# 12609   AZXNPVVLWKK1V:3RRCEFRB7NJMZF6NQFJVSF67B29B4C   (8.0, 10.0)        1
# 12610   AZXNPVVLWKK1V:3RRCEFRB7NJMZF6NQFJVSF67B29B4C   (8.0, 16.0)        2
# 12611   AZXNPVVLWKK1V:3RRCEFRB7NJMZF6NQFJVSF67B29B4C   (8.0, 22.0)        2
# 12612   AZXNPVVLWKK1V:3RRCEFRB7NJMZF6NQFJVSF67B29B4C   (8.0, 30.0)        0
# 12613   AZXNPVVLWKK1V:3RRCEFRB7NJMZF6NQFJVSF67B29B4C   (8.0, 40.0)        1
#
# [12614 rows x 3 columns]

# %%
performance_differences = []
for i in correct_by_subj_and_comparison['uniqueid'].unique():
    print(i)
    subj_df = correct_by_subj_and_comparison[correct_by_subj_and_comparison['uniqueid'] == i]
    print(subj_df[:2])
#     print(subj_df[subj_df['comparison'] == '(4.0, 40.0)']) # - subj_df[subj_df['comparison'] == '(28.0, 30.0)'].iloc[0])

performance_differences
# Out:
# A102WSFN62OS6I:3BWI6RSP7HGHP50Q24JSWZW2591E74
#                                         uniqueid  more_recent_probe  \
# 0  A102WSFN62OS6I:3BWI6RSP7HGHP50Q24JSWZW2591E74                4.0
# 1  A102WSFN62OS6I:3BWI6RSP7HGHP50Q24JSWZW2591E74                4.0
#
#    less_recent_probe  correct  comparison
# 0                6.0        0  (4.0, 6.0)
# 1                8.0        1  (4.0, 8.0)
# A1122EUMFXHF38:3KB8R4ZV1FE2BVZ7LGLW143A17IBGZ
#                                          uniqueid  more_recent_probe  \
# 34  A1122EUMFXHF38:3KB8R4ZV1FE2BVZ7LGLW143A17IBGZ                4.0
# 35  A1122EUMFXHF38:3KB8R4ZV1FE2BVZ7LGLW143A17IBGZ                4.0
#
#     less_recent_probe  correct comparison
# 34                6.0        1        NaN
# 35                8.0        1        NaN
# A116QUKBGZ6DLC:37M28K1J0RK7JNKGN86336BKBHBJAD
#                                          uniqueid  more_recent_probe  \
# 68  A116QUKBGZ6DLC:37M28K1J0RK7JNKGN86336BKBHBJAD                4.0
# 69  A116QUKBGZ6DLC:37M28K1J0RK7JNKGN86336BKBHBJAD                4.0
#
#     less_recent_probe  correct comparison
# 68                6.0        2        NaN
# 69                8.0        2        NaN
# A1198W1SPF1R4:3QEMNNSB2Y6CXZMQ6988QHEH5P9D73
#                                          uniqueid  more_recent_probe  \
# 102  A1198W1SPF1R4:3QEMNNSB2Y6CXZMQ6988QHEH5P9D73                4.0
# 103  A1198W1SPF1R4:3QEMNNSB2Y6CXZMQ6988QHEH5P9D73                4.0
#
#      less_recent_probe  correct comparison
# 102                6.0        0        NaN
# 103                8.0        1        NaN
# A121YWZJNUUZRJ:3IXQG4FA2U5NWLCZ7AFM9NHNXUNB98
#                                           uniqueid  more_recent_probe  \
# 136  A121YWZJNUUZRJ:3IXQG4FA2U5NWLCZ7AFM9NHNXUNB98                4.0
# 137  A121YWZJNUUZRJ:3IXQG4FA2U5NWLCZ7AFM9NHNXUNB98                4.0
#
#      less_recent_probe  correct comparison
# 136                6.0        1        NaN
# 137                8.0        1        NaN
# A129IJ184K6NNZ:3X3OR7WPZ07ZVPF1TVY2NUIHPIFL8C
#                                           uniqueid  more_recent_probe  \
# 170  A129IJ184K6NNZ:3X3OR7WPZ07ZVPF1TVY2NUIHPIFL8C                4.0
# 171  A129IJ184K6NNZ:3X3OR7WPZ07ZVPF1TVY2NUIHPIFL8C                4.0
#
#      less_recent_probe  correct comparison
# 170                6.0        3        NaN
# 171                8.0        3        NaN
# A12NT768CR36E5:3FE7TXL1LJUZ07TP5JXXUP48DOE2QJ
#                                           uniqueid  more_recent_probe  \
# 204  A12NT768CR36E5:3FE7TXL1LJUZ07TP5JXXUP48DOE2QJ                4.0
# 205  A12NT768CR36E5:3FE7TXL1LJUZ07TP5JXXUP48DOE2QJ                4.0
#
#      less_recent_probe  correct comparison
# 204                6.0        1        NaN
# 205                8.0        1        NaN
# A12QZC1FRXP8N5:3QBD8R3Z22Q6I9VWUKOHYZ66I1RO4S
#                                           uniqueid  more_recent_probe  \
# 238  A12QZC1FRXP8N5:3QBD8R3Z22Q6I9VWUKOHYZ66I1RO4S                4.0
# 239  A12QZC1FRXP8N5:3QBD8R3Z22Q6I9VWUKOHYZ66I1RO4S                4.0
#
#      less_recent_probe  correct comparison
# 238                6.0        2        NaN
# 239                8.0        1        NaN
# A12UVATD5QVM9D:3QUO65DNQVV5Z7PB9QFZB340HEEOUE
#                                           uniqueid  more_recent_probe  \
# 272  A12UVATD5QVM9D:3QUO65DNQVV5Z7PB9QFZB340HEEOUE                4.0
# 273  A12UVATD5QVM9D:3QUO65DNQVV5Z7PB9QFZB340HEEOUE                4.0
#
#      less_recent_probe  correct comparison
# 272                6.0        1        NaN
# 273                8.0        1        NaN
# A13GBA16BNTN1A:3LYA37P8IRU7DHVQB76BZWV39XOBKA
#                                           uniqueid  more_recent_probe  \
# 306  A13GBA16BNTN1A:3LYA37P8IRU7DHVQB76BZWV39XOBKA                4.0
# 307  A13GBA16BNTN1A:3LYA37P8IRU7DHVQB76BZWV39XOBKA                4.0
#
#      less_recent_probe  correct comparison
# 306                6.0        2        NaN
# 307                8.0        2        NaN
# A13THDIE8LTQ11:3M0NZ3JDP250DWD3AYI8JPJO29G5ZN
#                                           uniqueid  more_recent_probe  \
# 340  A13THDIE8LTQ11:3M0NZ3JDP250DWD3AYI8JPJO29G5ZN                4.0
# 341  A13THDIE8LTQ11:3M0NZ3JDP250DWD3AYI8JPJO29G5ZN                4.0
#
#      less_recent_probe  correct comparison
# 340                6.0        1        NaN
# 341                8.0        3        NaN
# A142FFFX25RI2B:3VNXK88KKDP25ZA5CR6MAZBU0M2V9X
#                                           uniqueid  more_recent_probe  \
# 374  A142FFFX25RI2B:3VNXK88KKDP25ZA5CR6MAZBU0M2V9X                4.0
# 375  A142FFFX25RI2B:3VNXK88KKDP25ZA5CR6MAZBU0M2V9X                4.0
#
#      less_recent_probe  correct comparison
# 374                6.0        1        NaN
# 375                8.0        1        NaN
# A14E4ISXVJVY6F:37TD41K0AIGOB504UGB812SV8OLCS7
#                                           uniqueid  more_recent_probe  \
# 408  A14E4ISXVJVY6F:37TD41K0AIGOB504UGB812SV8OLCS7                4.0
# 409  A14E4ISXVJVY6F:37TD41K0AIGOB504UGB812SV8OLCS7                4.0
#
#      less_recent_probe  correct comparison
# 408                6.0        1        NaN
# 409                8.0        2        NaN
# A14HW0XMI4R2ON:32EYX73OY1G8WKHR1IW35Y95S9PRUX
#                                           uniqueid  more_recent_probe  \
# 442  A14HW0XMI4R2ON:32EYX73OY1G8WKHR1IW35Y95S9PRUX                4.0
# 443  A14HW0XMI4R2ON:32EYX73OY1G8WKHR1IW35Y95S9PRUX                4.0
#
#      less_recent_probe  correct comparison
# 442                6.0        1        NaN
# 443                8.0        1        NaN
# A14N46NRBX3SG:3M23Y66PO3EZVOR3KPY5F20LBQCS68
#                                          uniqueid  more_recent_probe  \
# 476  A14N46NRBX3SG:3M23Y66PO3EZVOR3KPY5F20LBQCS68                4.0
# 477  A14N46NRBX3SG:3M23Y66PO3EZVOR3KPY5F20LBQCS68                4.0
#
#      less_recent_probe  correct comparison
# 476                6.0        1        NaN
# 477                8.0        0        NaN
# A14P6SH3OKKKZB:3I33IC7ZWG97DRM8GN0B4PP39EZA27
#                                           uniqueid  more_recent_probe  \
# 510  A14P6SH3OKKKZB:3I33IC7ZWG97DRM8GN0B4PP39EZA27                4.0
# 511  A14P6SH3OKKKZB:3I33IC7ZWG97DRM8GN0B4PP39EZA27                4.0
#
#      less_recent_probe  correct comparison
# 510                6.0        1        NaN
# 511                8.0        2        NaN
# A150QX2OXHGK8P:36WLNQG780H4RH3GFLV811IYOZSBEN
#                                           uniqueid  more_recent_probe  \
# 544  A150QX2OXHGK8P:36WLNQG780H4RH3GFLV811IYOZSBEN                4.0
# 545  A150QX2OXHGK8P:36WLNQG780H4RH3GFLV811IYOZSBEN                4.0
#
#      less_recent_probe  correct comparison
# 544                6.0        2        NaN
# 545                8.0        1        NaN
# A151XA53WYXVD7:3FTF2T8WLSPFKOAA21BIW1U883PW9A
#                                           uniqueid  more_recent_probe  \
# 578  A151XA53WYXVD7:3FTF2T8WLSPFKOAA21BIW1U883PW9A                4.0
# 579  A151XA53WYXVD7:3FTF2T8WLSPFKOAA21BIW1U883PW9A                4.0
#
#      less_recent_probe  correct comparison
# 578                6.0        3        NaN
# 579                8.0        3        NaN
# A15SQICSGF4P5:3FTYUGLFSVSXAV87IGTBSX0LEJFD5P
#                                          uniqueid  more_recent_probe  \
# 612  A15SQICSGF4P5:3FTYUGLFSVSXAV87IGTBSX0LEJFD5P                4.0
# 613  A15SQICSGF4P5:3FTYUGLFSVSXAV87IGTBSX0LEJFD5P                4.0
#
#      less_recent_probe  correct comparison
# 612                6.0        1        NaN
# 613                8.0        1        NaN
# A15V9BXNJXZXZX:3WJ1OXY92BNIZ6OXW49CEG26VESA8B
#                                           uniqueid  more_recent_probe  \
# 646  A15V9BXNJXZXZX:3WJ1OXY92BNIZ6OXW49CEG26VESA8B                4.0
# 647  A15V9BXNJXZXZX:3WJ1OXY92BNIZ6OXW49CEG26VESA8B                4.0
#
#      less_recent_probe  correct comparison
# 646                6.0        3        NaN
# 647                8.0        3        NaN
# A161VPQSXLLV8U:3HVVDCPGTFZ2T8EOF8YN8YG0CI8TYL
#                                           uniqueid  more_recent_probe  \
# 680  A161VPQSXLLV8U:3HVVDCPGTFZ2T8EOF8YN8YG0CI8TYL                4.0
# 681  A161VPQSXLLV8U:3HVVDCPGTFZ2T8EOF8YN8YG0CI8TYL                4.0
#
#      less_recent_probe  correct comparison
# 680                6.0        2        NaN
# 681                8.0        2        NaN
# A16335MOISDG1F:3E1QT0TDFQGX5O7V8S1PVEQP9MI8IZ
#                                           uniqueid  more_recent_probe  \
# 714  A16335MOISDG1F:3E1QT0TDFQGX5O7V8S1PVEQP9MI8IZ                4.0
# 715  A16335MOISDG1F:3E1QT0TDFQGX5O7V8S1PVEQP9MI8IZ                4.0
#
#      less_recent_probe  correct comparison
# 714                6.0        1        NaN
# 715                8.0        2        NaN
# A17B4ZMOXC7AUG:3LS2AMNW5GXD7EIUSHVU127BET7QOA
#                                           uniqueid  more_recent_probe  \
# 748  A17B4ZMOXC7AUG:3LS2AMNW5GXD7EIUSHVU127BET7QOA                4.0
# 749  A17B4ZMOXC7AUG:3LS2AMNW5GXD7EIUSHVU127BET7QOA                4.0
#
#      less_recent_probe  correct comparison
# 748                6.0        3        NaN
# 749                8.0        2        NaN
# A17R7WX5B0CKK6:3C8HJ7UOP81YL3Y92XZU0RUAO45ZM6
#                                           uniqueid  more_recent_probe  \
# 782  A17R7WX5B0CKK6:3C8HJ7UOP81YL3Y92XZU0RUAO45ZM6                4.0
# 783  A17R7WX5B0CKK6:3C8HJ7UOP81YL3Y92XZU0RUAO45ZM6                4.0
#
#      less_recent_probe  correct comparison
# 782                6.0        1        NaN
# 783                8.0        1        NaN
# A17WB66BXX4R0J:3MH9DQ757XJH7U8DL72R6UVYQ0EGUQ
#                                           uniqueid  more_recent_probe  \
# 816  A17WB66BXX4R0J:3MH9DQ757XJH7U8DL72R6UVYQ0EGUQ                4.0
# 817  A17WB66BXX4R0J:3MH9DQ757XJH7U8DL72R6UVYQ0EGUQ                4.0
#
#      less_recent_probe  correct comparison
# 816                6.0        2        NaN
# 817                8.0        2        NaN
# A17ZITDHO5KCH5:3AQF3RZ559PQRJMHE5Y683H6NB76FF
#                                           uniqueid  more_recent_probe  \
# 850  A17ZITDHO5KCH5:3AQF3RZ559PQRJMHE5Y683H6NB76FF                4.0
# 851  A17ZITDHO5KCH5:3AQF3RZ559PQRJMHE5Y683H6NB76FF                4.0
#
#      less_recent_probe  correct comparison
# 850                6.0        2        NaN
# 851                8.0        0        NaN
# A18H7SUNAHHADC:3AWETUDC93ZCPK8IHI128YNT7NVZIK
#                                           uniqueid  more_recent_probe  \
# 884  A18H7SUNAHHADC:3AWETUDC93ZCPK8IHI128YNT7NVZIK                4.0
# 885  A18H7SUNAHHADC:3AWETUDC93ZCPK8IHI128YNT7NVZIK                4.0
#
#      less_recent_probe  correct comparison
# 884                6.0        1        NaN
# 885                8.0        3        NaN
# A18V9Y7TEPM4KN:3E13VNJ1NO2FUONA97SAG43HU8I1IX
#                                           uniqueid  more_recent_probe  \
# 918  A18V9Y7TEPM4KN:3E13VNJ1NO2FUONA97SAG43HU8I1IX                4.0
# 919  A18V9Y7TEPM4KN:3E13VNJ1NO2FUONA97SAG43HU8I1IX                4.0
#
#      less_recent_probe  correct comparison
# 918                6.0        1        NaN
# 919                8.0        1        NaN
# A19B3ETU9NRV8H:3R3YRB5GRGAGX3VAZ7AHA8KVSXCAU3
#                                           uniqueid  more_recent_probe  \
# 952  A19B3ETU9NRV8H:3R3YRB5GRGAGX3VAZ7AHA8KVSXCAU3                4.0
# 953  A19B3ETU9NRV8H:3R3YRB5GRGAGX3VAZ7AHA8KVSXCAU3                4.0
#
#      less_recent_probe  correct comparison
# 952                6.0        2        NaN
# 953                8.0        1        NaN
# A19BG3DNCB8371:3QAVNHZ3ENBDED8GQTIGJLOCF6HLAI
#                                           uniqueid  more_recent_probe  \
# 986  A19BG3DNCB8371:3QAVNHZ3ENBDED8GQTIGJLOCF6HLAI                4.0
# 987  A19BG3DNCB8371:3QAVNHZ3ENBDED8GQTIGJLOCF6HLAI                4.0
#
#      less_recent_probe  correct comparison
# 986                6.0        3        NaN
# 987                8.0        2        NaN
# A19RH3XEBJPM5Q:3M0NZ3JDP250DWD3AYI8JPJO21P5ZG
#                                            uniqueid  more_recent_probe  \
# 1020  A19RH3XEBJPM5Q:3M0NZ3JDP250DWD3AYI8JPJO21P5ZG                4.0
# 1021  A19RH3XEBJPM5Q:3M0NZ3JDP250DWD3AYI8JPJO21P5ZG                4.0
#
#       less_recent_probe  correct comparison
# 1020                6.0        2        NaN
# 1021                8.0        3        NaN
# A1ARWNTZHGFG8Y:3U088ZLJVL0XOUMX25SP3QTF4Z10W7
#                                            uniqueid  more_recent_probe  \
# 1054  A1ARWNTZHGFG8Y:3U088ZLJVL0XOUMX25SP3QTF4Z10W7                4.0
# 1055  A1ARWNTZHGFG8Y:3U088ZLJVL0XOUMX25SP3QTF4Z10W7                4.0
#
#       less_recent_probe  correct comparison
# 1054                6.0        2        NaN
# 1055                8.0        2        NaN
# A1AYTKAQT201ZV:3GLB5JMZFY2VQSXRZCC2WURA50FGDD
#                                            uniqueid  more_recent_probe  \
# 1088  A1AYTKAQT201ZV:3GLB5JMZFY2VQSXRZCC2WURA50FGDD                4.0
# 1089  A1AYTKAQT201ZV:3GLB5JMZFY2VQSXRZCC2WURA50FGDD                4.0
#
#       less_recent_probe  correct comparison
# 1088                6.0        3        NaN
# 1089                8.0        3        NaN
# A1B81RS0ELC70N:36V4Q8R5ZL7P7BXIF1GH9YI6JTUMQT
#                                            uniqueid  more_recent_probe  \
# 1122  A1B81RS0ELC70N:36V4Q8R5ZL7P7BXIF1GH9YI6JTUMQT                4.0
# 1123  A1B81RS0ELC70N:36V4Q8R5ZL7P7BXIF1GH9YI6JTUMQT                4.0
#
#       less_recent_probe  correct comparison
# 1122                6.0        2        NaN
# 1123                8.0        2        NaN
# A1B8E9HE2BSIDQ:3K772S5NP9IEIU62FD54NCLWIE3HEI
#                                            uniqueid  more_recent_probe  \
# 1156  A1B8E9HE2BSIDQ:3K772S5NP9IEIU62FD54NCLWIE3HEI                4.0
# 1157  A1B8E9HE2BSIDQ:3K772S5NP9IEIU62FD54NCLWIE3HEI                4.0
#
#       less_recent_probe  correct comparison
# 1156                6.0        2        NaN
# 1157                8.0        2        NaN
# A1BFL3OKT1W4JD:34T446B1C1LOAWGSLESORWMCCBQ0CP
#                                            uniqueid  more_recent_probe  \
# 1190  A1BFL3OKT1W4JD:34T446B1C1LOAWGSLESORWMCCBQ0CP                4.0
# 1191  A1BFL3OKT1W4JD:34T446B1C1LOAWGSLESORWMCCBQ0CP                4.0
#
#       less_recent_probe  correct comparison
# 1190                6.0        1        NaN
# 1191                8.0        1        NaN
# A1BLHM2IDH7DH4:3FDJT1UU75F5O1EHAXFYWAVBZDAK5E
#                                            uniqueid  more_recent_probe  \
# 1224  A1BLHM2IDH7DH4:3FDJT1UU75F5O1EHAXFYWAVBZDAK5E                4.0
# 1225  A1BLHM2IDH7DH4:3FDJT1UU75F5O1EHAXFYWAVBZDAK5E                4.0
#
#       less_recent_probe  correct comparison
# 1224                6.0        2        NaN
# 1225                8.0        2        NaN
# A1C508BB6CF8VR:3LBXNTKX0S2U9OF0C674YK8FG5HX9P
#                                            uniqueid  more_recent_probe  \
# 1258  A1C508BB6CF8VR:3LBXNTKX0S2U9OF0C674YK8FG5HX9P                4.0
# 1259  A1C508BB6CF8VR:3LBXNTKX0S2U9OF0C674YK8FG5HX9P                4.0
#
#       less_recent_probe  correct comparison
# 1258                6.0        0        NaN
# 1259                8.0        1        NaN
# A1CB9NR3SN4VMY:38F71OA9GU3SGM791L5NXZESCZBMF5
#                                            uniqueid  more_recent_probe  \
# 1292  A1CB9NR3SN4VMY:38F71OA9GU3SGM791L5NXZESCZBMF5                4.0
# 1293  A1CB9NR3SN4VMY:38F71OA9GU3SGM791L5NXZESCZBMF5                4.0
#
#       less_recent_probe  correct comparison
# 1292                6.0        1        NaN
# 1293                8.0        0        NaN
# A1CKIYN01NV9GJ:30ZX6P7VF92IEKPCATDOXOSMZTKJ27
#                                            uniqueid  more_recent_probe  \
# 1326  A1CKIYN01NV9GJ:30ZX6P7VF92IEKPCATDOXOSMZTKJ27                4.0
# 1327  A1CKIYN01NV9GJ:30ZX6P7VF92IEKPCATDOXOSMZTKJ27                4.0
#
#       less_recent_probe  correct comparison
# 1326                6.0        1        NaN
# 1327                8.0        2        NaN
# A1CPJ9Q4UQ0FZ3:34PGFRQONPI4Q0NJOD2VLV8B4LHWJB
#                                            uniqueid  more_recent_probe  \
# 1360  A1CPJ9Q4UQ0FZ3:34PGFRQONPI4Q0NJOD2VLV8B4LHWJB                4.0
# 1361  A1CPJ9Q4UQ0FZ3:34PGFRQONPI4Q0NJOD2VLV8B4LHWJB                4.0
#
#       less_recent_probe  correct comparison
# 1360                6.0        1        NaN
# 1361                8.0        2        NaN
# A1D26DHX9CDRGI:3XM0HYN6NL66VB4QYQD9WLNN5VFPEE
#                                            uniqueid  more_recent_probe  \
# 1394  A1D26DHX9CDRGI:3XM0HYN6NL66VB4QYQD9WLNN5VFPEE                4.0
# 1395  A1D26DHX9CDRGI:3XM0HYN6NL66VB4QYQD9WLNN5VFPEE                4.0
#
#       less_recent_probe  correct comparison
# 1394                6.0        2        NaN
# 1395                8.0        1        NaN
# A1D5K3HSPDH9B2:3HYA4D452SQ29I3GR3M3IQ0U5W0F2G
#                                            uniqueid  more_recent_probe  \
# 1428  A1D5K3HSPDH9B2:3HYA4D452SQ29I3GR3M3IQ0U5W0F2G                4.0
# 1429  A1D5K3HSPDH9B2:3HYA4D452SQ29I3GR3M3IQ0U5W0F2G                4.0
#
#       less_recent_probe  correct comparison
# 1428                6.0        1        NaN
# 1429                8.0        1        NaN
# A1DGGXKHU126F7:3Z4AIRP3C7KCKJC58TSBJEQWITD1X4
#                                            uniqueid  more_recent_probe  \
# 1462  A1DGGXKHU126F7:3Z4AIRP3C7KCKJC58TSBJEQWITD1X4                4.0
# 1463  A1DGGXKHU126F7:3Z4AIRP3C7KCKJC58TSBJEQWITD1X4                4.0
#
#       less_recent_probe  correct comparison
# 1462                6.0        2        NaN
# 1463                8.0        3        NaN
# A1DKL7KT4YB97L:3QL2OFSM97PRVS8ZMKUM28IPK44CNF
#                                            uniqueid  more_recent_probe  \
# 1496  A1DKL7KT4YB97L:3QL2OFSM97PRVS8ZMKUM28IPK44CNF                4.0
# 1497  A1DKL7KT4YB97L:3QL2OFSM97PRVS8ZMKUM28IPK44CNF                4.0
#
#       less_recent_probe  correct comparison
# 1496                6.0        2        NaN
# 1497                8.0        3        NaN
# A1EGQFVJZ8EDGF:37Q970SNZFF4O2Q6EJMOK6943EAS1M
#                                            uniqueid  more_recent_probe  \
# 1530  A1EGQFVJZ8EDGF:37Q970SNZFF4O2Q6EJMOK6943EAS1M                4.0
# 1531  A1EGQFVJZ8EDGF:37Q970SNZFF4O2Q6EJMOK6943EAS1M                4.0
#
#       less_recent_probe  correct comparison
# 1530                6.0        0        NaN
# 1531                8.0        2        NaN
# A1EII5EWOTBDK9:3C2NJ6JBKBOEXAGXPR5GQV938LGN2M
#                                            uniqueid  more_recent_probe  \
# 1564  A1EII5EWOTBDK9:3C2NJ6JBKBOEXAGXPR5GQV938LGN2M                4.0
# 1565  A1EII5EWOTBDK9:3C2NJ6JBKBOEXAGXPR5GQV938LGN2M                4.0
#
#       less_recent_probe  correct comparison
# 1564                6.0        2        NaN
# 1565                8.0        2        NaN
# A1EMO2ELY989L1:3PWWM24LHT5TU3TTJPGX8YJ8JQI28E
#                                            uniqueid  more_recent_probe  \
# 1598  A1EMO2ELY989L1:3PWWM24LHT5TU3TTJPGX8YJ8JQI28E                4.0
# 1599  A1EMO2ELY989L1:3PWWM24LHT5TU3TTJPGX8YJ8JQI28E                4.0
#
#       less_recent_probe  correct comparison
# 1598                6.0        2        NaN
# 1599                8.0        2        NaN
# A1EPVK4F4ATB1:3BQU611VFQR48SX29Q1QIHMX9UJ99V
#                                           uniqueid  more_recent_probe  \
# 1632  A1EPVK4F4ATB1:3BQU611VFQR48SX29Q1QIHMX9UJ99V                4.0
# 1633  A1EPVK4F4ATB1:3BQU611VFQR48SX29Q1QIHMX9UJ99V                4.0
#
#       less_recent_probe  correct comparison
# 1632                6.0        2        NaN
# 1633                8.0        2        NaN
# A1ES9CZ99YS7O2:31HQ4X3T3THHE9UA7T474LII1KFSLS
#                                            uniqueid  more_recent_probe  \
# 1666  A1ES9CZ99YS7O2:31HQ4X3T3THHE9UA7T474LII1KFSLS                4.0
# 1667  A1ES9CZ99YS7O2:31HQ4X3T3THHE9UA7T474LII1KFSLS                4.0
#
#       less_recent_probe  correct comparison
# 1666                6.0        2        NaN
# 1667                8.0        1        NaN
# A1EVO152C6YOER:3CFJTT4SXUXT5A2CYN9JHEUUXUGI79
#                                            uniqueid  more_recent_probe  \
# 1700  A1EVO152C6YOER:3CFJTT4SXUXT5A2CYN9JHEUUXUGI79                4.0
# 1701  A1EVO152C6YOER:3CFJTT4SXUXT5A2CYN9JHEUUXUGI79                4.0
#
#       less_recent_probe  correct comparison
# 1700                6.0        1        NaN
# 1701                8.0        2        NaN
# A1F8F956ETH1TA:3YMU66OBIOFC282TL8VSNF68VUIHGZ
#                                            uniqueid  more_recent_probe  \
# 1734  A1F8F956ETH1TA:3YMU66OBIOFC282TL8VSNF68VUIHGZ                4.0
# 1735  A1F8F956ETH1TA:3YMU66OBIOFC282TL8VSNF68VUIHGZ                4.0
#
#       less_recent_probe  correct comparison
# 1734                6.0        2        NaN
# 1735                8.0        3        NaN
# A1F9Y1M4EA0JWE:31T4R4OBOTN2S7GC6DDX6BWZKXPC7A
#                                            uniqueid  more_recent_probe  \
# 1768  A1F9Y1M4EA0JWE:31T4R4OBOTN2S7GC6DDX6BWZKXPC7A                4.0
# 1769  A1F9Y1M4EA0JWE:31T4R4OBOTN2S7GC6DDX6BWZKXPC7A                4.0
#
#       less_recent_probe  correct comparison
# 1768                6.0        1        NaN
# 1769                8.0        1        NaN
# A1FAHGRK0YXQJ8:3SB5N7Y3O4B1R8WXN0O7HN7RA3HG0E
#                                            uniqueid  more_recent_probe  \
# 1802  A1FAHGRK0YXQJ8:3SB5N7Y3O4B1R8WXN0O7HN7RA3HG0E                4.0
# 1803  A1FAHGRK0YXQJ8:3SB5N7Y3O4B1R8WXN0O7HN7RA3HG0E                4.0
#
#       less_recent_probe  correct comparison
# 1802                6.0        0        NaN
# 1803                8.0        2        NaN
# A1FM638CHGPC1M:3II4UPYCOKEM3HR528HEQ8VCAOFQDA
#                                            uniqueid  more_recent_probe  \
# 1836  A1FM638CHGPC1M:3II4UPYCOKEM3HR528HEQ8VCAOFQDA                4.0
# 1837  A1FM638CHGPC1M:3II4UPYCOKEM3HR528HEQ8VCAOFQDA                4.0
#
#       less_recent_probe  correct comparison
# 1836                6.0        2        NaN
# 1837                8.0        2        NaN
# A1FX3LZ259KP7J:3CTOC39K38XP0LMIG5UJTF9UA95J7M
#                                            uniqueid  more_recent_probe  \
# 1870  A1FX3LZ259KP7J:3CTOC39K38XP0LMIG5UJTF9UA95J7M                4.0
# 1871  A1FX3LZ259KP7J:3CTOC39K38XP0LMIG5UJTF9UA95J7M                4.0
#
#       less_recent_probe  correct comparison
# 1870                6.0        2        NaN
# 1871                8.0        1        NaN
# A1G93GASJ0CIZU:3WMINLGALCAKB9EADGPHG2YPLX3CAT
#                                            uniqueid  more_recent_probe  \
# 1904  A1G93GASJ0CIZU:3WMINLGALCAKB9EADGPHG2YPLX3CAT                4.0
# 1905  A1G93GASJ0CIZU:3WMINLGALCAKB9EADGPHG2YPLX3CAT                4.0
#
#       less_recent_probe  correct comparison
# 1904                6.0        2        NaN
# 1905                8.0        1        NaN
# A1GEO1VUUQQ9K2:3COPXFW7XCJ9HBW0UCOCUG0SQPMPK4
#                                            uniqueid  more_recent_probe  \
# 1938  A1GEO1VUUQQ9K2:3COPXFW7XCJ9HBW0UCOCUG0SQPMPK4                4.0
# 1939  A1GEO1VUUQQ9K2:3COPXFW7XCJ9HBW0UCOCUG0SQPMPK4                4.0
#
#       less_recent_probe  correct comparison
# 1938                6.0        1        NaN
# 1939                8.0        3        NaN
# A1GR7QZWVJ1GZQ:37ZHEEHM6XTEF7KTDK2WD8S5FWM736
#                                            uniqueid  more_recent_probe  \
# 1972  A1GR7QZWVJ1GZQ:37ZHEEHM6XTEF7KTDK2WD8S5FWM736                4.0
# 1973  A1GR7QZWVJ1GZQ:37ZHEEHM6XTEF7KTDK2WD8S5FWM736                4.0
#
#       less_recent_probe  correct comparison
# 1972                6.0        1        NaN
# 1973                8.0        3        NaN
# A1H5Q9HRH4RPZU:3PJUZCGDJ7N4UNES4YVCILRMPW998U
#                                            uniqueid  more_recent_probe  \
# 2006  A1H5Q9HRH4RPZU:3PJUZCGDJ7N4UNES4YVCILRMPW998U                4.0
# 2007  A1H5Q9HRH4RPZU:3PJUZCGDJ7N4UNES4YVCILRMPW998U                4.0
#
#       less_recent_probe  correct comparison
# 2006                6.0        1        NaN
# 2007                8.0        2        NaN
# A1H7KE62OOEYWG:3ZOTGHDK5JIPKUX7KLKZW2MCXPEOS0
#                                            uniqueid  more_recent_probe  \
# 2040  A1H7KE62OOEYWG:3ZOTGHDK5JIPKUX7KLKZW2MCXPEOS0                4.0
# 2041  A1H7KE62OOEYWG:3ZOTGHDK5JIPKUX7KLKZW2MCXPEOS0                4.0
#
#       less_recent_probe  correct comparison
# 2040                6.0        1        NaN
# 2041                8.0        3        NaN
# A1HENLDLQEO5BZ:3B2X28YI3XM0E2A193CAPDQL8EIB67
#                                            uniqueid  more_recent_probe  \
# 2074  A1HENLDLQEO5BZ:3B2X28YI3XM0E2A193CAPDQL8EIB67                4.0
# 2075  A1HENLDLQEO5BZ:3B2X28YI3XM0E2A193CAPDQL8EIB67                4.0
#
#       less_recent_probe  correct comparison
# 2074                6.0        2        NaN
# 2075                8.0        1        NaN
# A1HLDOM6JTYYI2:35DR22AR5ER8UMQKVX6U775THQAX32
#                                            uniqueid  more_recent_probe  \
# 2108  A1HLDOM6JTYYI2:35DR22AR5ER8UMQKVX6U775THQAX32                4.0
# 2109  A1HLDOM6JTYYI2:35DR22AR5ER8UMQKVX6U775THQAX32                4.0
#
#       less_recent_probe  correct comparison
# 2108                6.0        1        NaN
# 2109                8.0        2        NaN
# A1HR8IRDC07FO9:3SBEHTYCWOACKUYDLWZJURER21BIYD
#                                            uniqueid  more_recent_probe  \
# 2142  A1HR8IRDC07FO9:3SBEHTYCWOACKUYDLWZJURER21BIYD                4.0
# 2143  A1HR8IRDC07FO9:3SBEHTYCWOACKUYDLWZJURER21BIYD                4.0
#
#       less_recent_probe  correct comparison
# 2142                6.0        3        NaN
# 2143                8.0        1        NaN
# A1HSEVGZBWJUPH:3VHP9MDGRORF70VIOWB9U39GHNDFCP
#                                            uniqueid  more_recent_probe  \
# 2176  A1HSEVGZBWJUPH:3VHP9MDGRORF70VIOWB9U39GHNDFCP                4.0
# 2177  A1HSEVGZBWJUPH:3VHP9MDGRORF70VIOWB9U39GHNDFCP                4.0
#
#       less_recent_probe  correct comparison
# 2176                6.0        2        NaN
# 2177                8.0        2        NaN
# A1I7LQ7O0HR5WH:33CUSNVVNOJ4GIVIZ6PYIPWB5IH88E
#                                            uniqueid  more_recent_probe  \
# 2210  A1I7LQ7O0HR5WH:33CUSNVVNOJ4GIVIZ6PYIPWB5IH88E                4.0
# 2211  A1I7LQ7O0HR5WH:33CUSNVVNOJ4GIVIZ6PYIPWB5IH88E                4.0
#
#       less_recent_probe  correct comparison
# 2210                6.0        1        NaN
# 2211                8.0        2        NaN
# A1I9RLJQ0BYN21:3M23Y66PO3EZVOR3KPY5F20LBPQS6K
#                                            uniqueid  more_recent_probe  \
# 2244  A1I9RLJQ0BYN21:3M23Y66PO3EZVOR3KPY5F20LBPQS6K                4.0
# 2245  A1I9RLJQ0BYN21:3M23Y66PO3EZVOR3KPY5F20LBPQS6K                4.0
#
#       less_recent_probe  correct comparison
# 2244                6.0        1        NaN
# 2245                8.0        2        NaN
# A1IGKJ200N82S9:3TGOYF991YT0CC985CR8A9WP08RUU3
#                                            uniqueid  more_recent_probe  \
# 2278  A1IGKJ200N82S9:3TGOYF991YT0CC985CR8A9WP08RUU3                4.0
# 2279  A1IGKJ200N82S9:3TGOYF991YT0CC985CR8A9WP08RUU3                4.0
#
#       less_recent_probe  correct comparison
# 2278                6.0        1        NaN
# 2279                8.0        3        NaN
# A1IIR61XKDC6FS:3LJ7UR74RIKO0OVKT5O4JA61SZCN4I
#                                            uniqueid  more_recent_probe  \
# 2312  A1IIR61XKDC6FS:3LJ7UR74RIKO0OVKT5O4JA61SZCN4I                4.0
# 2313  A1IIR61XKDC6FS:3LJ7UR74RIKO0OVKT5O4JA61SZCN4I                4.0
#
#       less_recent_probe  correct comparison
# 2312                6.0        1        NaN
# 2313                8.0        3        NaN
# A1IL5P5H5VRW0D:3VNXK88KKDP25ZA5CR6MAZBU0UT9VI
#                                            uniqueid  more_recent_probe  \
# 2346  A1IL5P5H5VRW0D:3VNXK88KKDP25ZA5CR6MAZBU0UT9VI                4.0
# 2347  A1IL5P5H5VRW0D:3VNXK88KKDP25ZA5CR6MAZBU0UT9VI                4.0
#
#       less_recent_probe  correct comparison
# 2346                6.0        2        NaN
# 2347                8.0        1        NaN
# A1J2ZU4AH7V6N6:36AHBNMV1SJVCJIRTIY83UYE9OJDY5
#                                            uniqueid  more_recent_probe  \
# 2380  A1J2ZU4AH7V6N6:36AHBNMV1SJVCJIRTIY83UYE9OJDY5                4.0
# 2381  A1J2ZU4AH7V6N6:36AHBNMV1SJVCJIRTIY83UYE9OJDY5                4.0
#
#       less_recent_probe  correct comparison
# 2380                6.0        3        NaN
# 2381                8.0        1        NaN
# A1J39RAV7TKEMF:3NQL1CS15SFH60IDK3Y29G4L93DYVV
#                                            uniqueid  more_recent_probe  \
# 2414  A1J39RAV7TKEMF:3NQL1CS15SFH60IDK3Y29G4L93DYVV                4.0
# 2415  A1J39RAV7TKEMF:3NQL1CS15SFH60IDK3Y29G4L93DYVV                4.0
#
#       less_recent_probe  correct comparison
# 2414                6.0        2        NaN
# 2415                8.0        2        NaN
# A1J5OW12TRQSOW:3TYCR1GOTDQEFLGO2LYF0EFLOZNZLC
#                                            uniqueid  more_recent_probe  \
# 2448  A1J5OW12TRQSOW:3TYCR1GOTDQEFLGO2LYF0EFLOZNZLC                4.0
# 2449  A1J5OW12TRQSOW:3TYCR1GOTDQEFLGO2LYF0EFLOZNZLC                4.0
#
#       less_recent_probe  correct comparison
# 2448                6.0        1        NaN
# 2449                8.0        1        NaN
# A1J6CZ176U6GDT:39ZSFO5CA93RYWYETDNU37NEISVUJ8
#                                            uniqueid  more_recent_probe  \
# 2482  A1J6CZ176U6GDT:39ZSFO5CA93RYWYETDNU37NEISVUJ8                4.0
# 2483  A1J6CZ176U6GDT:39ZSFO5CA93RYWYETDNU37NEISVUJ8                4.0
#
#       less_recent_probe  correct comparison
# 2482                6.0        2        NaN
# 2483                8.0        0        NaN
# A1JCI4LMNRO2DL:3IHR8NYAM88O397X9K1WNZBWS6O4PQ
#                                            uniqueid  more_recent_probe  \
# 2516  A1JCI4LMNRO2DL:3IHR8NYAM88O397X9K1WNZBWS6O4PQ                4.0
# 2517  A1JCI4LMNRO2DL:3IHR8NYAM88O397X9K1WNZBWS6O4PQ                4.0
#
#       less_recent_probe  correct comparison
# 2516                6.0        3        NaN
# 2517                8.0        3        NaN
# A1JL3HCA0MK9UI:3U84XHCDIDKIHD93WTZYEXDA2DL4ZH
#                                            uniqueid  more_recent_probe  \
# 2550  A1JL3HCA0MK9UI:3U84XHCDIDKIHD93WTZYEXDA2DL4ZH                4.0
# 2551  A1JL3HCA0MK9UI:3U84XHCDIDKIHD93WTZYEXDA2DL4ZH                4.0
#
#       less_recent_probe  correct comparison
# 2550                6.0        0        NaN
# 2551                8.0        1        NaN
# A1JT6ZF5PMQBM1:3DY4FPOOA2V89Z6R68681KBO6GYRVM
#                                            uniqueid  more_recent_probe  \
# 2584  A1JT6ZF5PMQBM1:3DY4FPOOA2V89Z6R68681KBO6GYRVM                4.0
# 2585  A1JT6ZF5PMQBM1:3DY4FPOOA2V89Z6R68681KBO6GYRVM                4.0
#
#       less_recent_probe  correct comparison
# 2584                6.0        1        NaN
# 2585                8.0        2        NaN
# A1KCSGTT6Y26LH:3GU1KF0O4J88O8S6OZBJVDH226ABPO
#                                            uniqueid  more_recent_probe  \
# 2618  A1KCSGTT6Y26LH:3GU1KF0O4J88O8S6OZBJVDH226ABPO                4.0
# 2619  A1KCSGTT6Y26LH:3GU1KF0O4J88O8S6OZBJVDH226ABPO                4.0
#
#       less_recent_probe  correct comparison
# 2618                6.0        2        NaN
# 2619                8.0        1        NaN
# A1L5A88C9PPK5L:3U5NZHP4LS9IFLVSORLFHOK0XKLPHQ
#                                            uniqueid  more_recent_probe  \
# 2652  A1L5A88C9PPK5L:3U5NZHP4LS9IFLVSORLFHOK0XKLPHQ                4.0
# 2653  A1L5A88C9PPK5L:3U5NZHP4LS9IFLVSORLFHOK0XKLPHQ                4.0
#
#       less_recent_probe  correct comparison
# 2652                6.0        2        NaN
# 2653                8.0        2        NaN
# A1L7MU9FO4TAC2:3KJYX6QCMAIRBBNEY3XZZTPXXBEVJX
#                                            uniqueid  more_recent_probe  \
# 2686  A1L7MU9FO4TAC2:3KJYX6QCMAIRBBNEY3XZZTPXXBEVJX                4.0
# 2687  A1L7MU9FO4TAC2:3KJYX6QCMAIRBBNEY3XZZTPXXBEVJX                4.0
#
#       less_recent_probe  correct comparison
# 2686                6.0        1        NaN
# 2687                8.0        2        NaN
# A1MD74JPL7E9PK:3A4NIXBJ776EGEH5NW8LSCJCAVRLM4
#                                            uniqueid  more_recent_probe  \
# 2720  A1MD74JPL7E9PK:3A4NIXBJ776EGEH5NW8LSCJCAVRLM4                4.0
# 2721  A1MD74JPL7E9PK:3A4NIXBJ776EGEH5NW8LSCJCAVRLM4                4.0
#
#       less_recent_probe  correct comparison
# 2720                6.0        1        NaN
# 2721                8.0        1        NaN
# A1NFRIHID90D7C:3W8CV64QJ36XNYFL72PIVYKLSFI9HS
#                                            uniqueid  more_recent_probe  \
# 2754  A1NFRIHID90D7C:3W8CV64QJ36XNYFL72PIVYKLSFI9HS                4.0
# 2755  A1NFRIHID90D7C:3W8CV64QJ36XNYFL72PIVYKLSFI9HS                4.0
#
#       less_recent_probe  correct comparison
# 2754                6.0        1        NaN
# 2755                8.0        1        NaN
# A1NG504QI5LI62:3VBEN272ML61SHG9W27RRTDA53TSGM
#                                            uniqueid  more_recent_probe  \
# 2788  A1NG504QI5LI62:3VBEN272ML61SHG9W27RRTDA53TSGM                4.0
# 2789  A1NG504QI5LI62:3VBEN272ML61SHG9W27RRTDA53TSGM                4.0
#
#       less_recent_probe  correct comparison
# 2788                6.0        3        NaN
# 2789                8.0        2        NaN
# A1O7CGNZFBLBDZ:3Z9WI9EOZ0VH4UYCBZG7L7Y1314KHR
#                                            uniqueid  more_recent_probe  \
# 2822  A1O7CGNZFBLBDZ:3Z9WI9EOZ0VH4UYCBZG7L7Y1314KHR                4.0
# 2823  A1O7CGNZFBLBDZ:3Z9WI9EOZ0VH4UYCBZG7L7Y1314KHR                4.0
#
#       less_recent_probe  correct comparison
# 2822                6.0        3        NaN
# 2823                8.0        0        NaN
# A1OOCYEFLAJD98:33FOTY3KENSOHL1AHXWO515MHBZC1N
#                                            uniqueid  more_recent_probe  \
# 2856  A1OOCYEFLAJD98:33FOTY3KENSOHL1AHXWO515MHBZC1N                4.0
# 2857  A1OOCYEFLAJD98:33FOTY3KENSOHL1AHXWO515MHBZC1N                4.0
#
#       less_recent_probe  correct comparison
# 2856                6.0        2        NaN
# 2857                8.0        2        NaN
# A1PTX4IB9R34LI:3L6L49WXW14KAZPEP5SIPT6F1FL54L
#                                            uniqueid  more_recent_probe  \
# 2890  A1PTX4IB9R34LI:3L6L49WXW14KAZPEP5SIPT6F1FL54L                4.0
# 2891  A1PTX4IB9R34LI:3L6L49WXW14KAZPEP5SIPT6F1FL54L                4.0
#
#       less_recent_probe  correct comparison
# 2890                6.0        2        NaN
# 2891                8.0        1        NaN
# A1PVXVDFI5OU8B:3TYCR1GOTDQEFLGO2LYF0EFLN1LLZZ
#                                            uniqueid  more_recent_probe  \
# 2924  A1PVXVDFI5OU8B:3TYCR1GOTDQEFLGO2LYF0EFLN1LLZZ                4.0
# 2925  A1PVXVDFI5OU8B:3TYCR1GOTDQEFLGO2LYF0EFLN1LLZZ                4.0
#
#       less_recent_probe  correct comparison
# 2924                6.0        0        NaN
# 2925                8.0        1        NaN
# A1Q6ZK8NKT4I93:3LRLIPTPERG2U7QY5T6F4LBXRQEAKB
#                                            uniqueid  more_recent_probe  \
# 2958  A1Q6ZK8NKT4I93:3LRLIPTPERG2U7QY5T6F4LBXRQEAKB                4.0
# 2959  A1Q6ZK8NKT4I93:3LRLIPTPERG2U7QY5T6F4LBXRQEAKB                4.0
#
#       less_recent_probe  correct comparison
# 2958                6.0        3        NaN
# 2959                8.0        2        NaN
# A1QMJNJ5FGC09:3634BBTX0P16K3HIG67V567BWQLIFG
#                                           uniqueid  more_recent_probe  \
# 2992  A1QMJNJ5FGC09:3634BBTX0P16K3HIG67V567BWQLIFG                4.0
# 2993  A1QMJNJ5FGC09:3634BBTX0P16K3HIG67V567BWQLIFG                4.0
#
#       less_recent_probe  correct comparison
# 2992                6.0        2        NaN
# 2993                8.0        3        NaN
# A1QXJZFA5NVGM3:3I0BTBYZAYS1DZHXH6ADONEVG7V0Y1
#                                            uniqueid  more_recent_probe  \
# 3026  A1QXJZFA5NVGM3:3I0BTBYZAYS1DZHXH6ADONEVG7V0Y1                4.0
# 3027  A1QXJZFA5NVGM3:3I0BTBYZAYS1DZHXH6ADONEVG7V0Y1                4.0
#
#       less_recent_probe  correct comparison
# 3026                6.0        1        NaN
# 3027                8.0        1        NaN
# A1QZOJA1OUV4WO:3P4RDNWND6DMP53EZWYGK4Z3OPGJIH
#                                            uniqueid  more_recent_probe  \
# 3060  A1QZOJA1OUV4WO:3P4RDNWND6DMP53EZWYGK4Z3OPGJIH                4.0
# 3061  A1QZOJA1OUV4WO:3P4RDNWND6DMP53EZWYGK4Z3OPGJIH                4.0
#
#       less_recent_probe  correct comparison
# 3060                6.0        2        NaN
# 3061                8.0        2        NaN
# A1R033FHHMVPXN:3SB4CE2TJW28E7P54CL4UFJZMFTAXV
#                                            uniqueid  more_recent_probe  \
# 3094  A1R033FHHMVPXN:3SB4CE2TJW28E7P54CL4UFJZMFTAXV                4.0
# 3095  A1R033FHHMVPXN:3SB4CE2TJW28E7P54CL4UFJZMFTAXV                4.0
#
#       less_recent_probe  correct comparison
# 3094                6.0        3        NaN
# 3095                8.0        0        NaN
# A1R5JNC2LO6X1S:3M81GAB8A1QTOKTLOCQ8VI7C7UPBQS
#                                            uniqueid  more_recent_probe  \
# 3128  A1R5JNC2LO6X1S:3M81GAB8A1QTOKTLOCQ8VI7C7UPBQS                4.0
# 3129  A1R5JNC2LO6X1S:3M81GAB8A1QTOKTLOCQ8VI7C7UPBQS                4.0
#
#       less_recent_probe  correct comparison
# 3128                6.0        2        NaN
# 3129                8.0        3        NaN
# A1RB4N7CLORR05:3RYC5T2D740V4F9VKWX9VSM6KK5RPT
#                                            uniqueid  more_recent_probe  \
# 3162  A1RB4N7CLORR05:3RYC5T2D740V4F9VKWX9VSM6KK5RPT                4.0
# 3163  A1RB4N7CLORR05:3RYC5T2D740V4F9VKWX9VSM6KK5RPT                4.0
#
#       less_recent_probe  correct comparison
# 3162                6.0        0        NaN
# 3163                8.0        3        NaN
# A1RI7QA7FX6I6I:39KFRKBFIO2MGG9GJRCOEOADD2QOYD
#                                            uniqueid  more_recent_probe  \
# 3196  A1RI7QA7FX6I6I:39KFRKBFIO2MGG9GJRCOEOADD2QOYD                4.0
# 3197  A1RI7QA7FX6I6I:39KFRKBFIO2MGG9GJRCOEOADD2QOYD                4.0
#
#       less_recent_probe  correct comparison
# 3196                6.0        1        NaN
# 3197                8.0        3        NaN
# A1S2EXYEG5I8HW:3X0H8UUIT2VXP369B7B9DWZY0H5SWO
#                                            uniqueid  more_recent_probe  \
# 3230  A1S2EXYEG5I8HW:3X0H8UUIT2VXP369B7B9DWZY0H5SWO                4.0
# 3231  A1S2EXYEG5I8HW:3X0H8UUIT2VXP369B7B9DWZY0H5SWO                4.0
#
#       less_recent_probe  correct comparison
# 3230                6.0        1        NaN
# 3231                8.0        2        NaN
# A1S5NX2HYXS2YO:3VSOLARPKCGITQ8MSH0GR4JB92993E
#                                            uniqueid  more_recent_probe  \
# 3264  A1S5NX2HYXS2YO:3VSOLARPKCGITQ8MSH0GR4JB92993E                4.0
# 3265  A1S5NX2HYXS2YO:3VSOLARPKCGITQ8MSH0GR4JB92993E                4.0
#
#       less_recent_probe  correct comparison
# 3264                6.0        0        NaN
# 3265                8.0        3        NaN
# A1SCF3L6LTFQHF:3WYGZ5XF3XM6U3CSMTS6PL53CKASKP
#                                            uniqueid  more_recent_probe  \
# 3298  A1SCF3L6LTFQHF:3WYGZ5XF3XM6U3CSMTS6PL53CKASKP                4.0
# 3299  A1SCF3L6LTFQHF:3WYGZ5XF3XM6U3CSMTS6PL53CKASKP                4.0
#
#       less_recent_probe  correct comparison
# 3298                6.0        2        NaN
# 3299                8.0        2        NaN
# A1SJLXB0XFCJ97:3GDTJDAPVVIJ17XMT7ZHN7X6PV7M8X
#                                            uniqueid  more_recent_probe  \
# 3332  A1SJLXB0XFCJ97:3GDTJDAPVVIJ17XMT7ZHN7X6PV7M8X                4.0
# 3333  A1SJLXB0XFCJ97:3GDTJDAPVVIJ17XMT7ZHN7X6PV7M8X                4.0
#
#       less_recent_probe  correct comparison
# 3332                6.0        3        NaN
# 3333                8.0        0        NaN
# A1STC10BXEP495:3ATPCQ38J9HXECFF9876DTQ8OLNAY1
#                                            uniqueid  more_recent_probe  \
# 3366  A1STC10BXEP495:3ATPCQ38J9HXECFF9876DTQ8OLNAY1                4.0
# 3367  A1STC10BXEP495:3ATPCQ38J9HXECFF9876DTQ8OLNAY1                4.0
#
#       less_recent_probe  correct comparison
# 3366                6.0        1        NaN
# 3367                8.0        1        NaN
# A1SVV9UHWC9ENA:3PIWWX1FJKDIKGNKHEJGW5E31D7JJD
#                                            uniqueid  more_recent_probe  \
# 3400  A1SVV9UHWC9ENA:3PIWWX1FJKDIKGNKHEJGW5E31D7JJD                4.0
# 3401  A1SVV9UHWC9ENA:3PIWWX1FJKDIKGNKHEJGW5E31D7JJD                4.0
#
#       less_recent_probe  correct comparison
# 3400                6.0        2        NaN
# 3401                8.0        2        NaN
# A1TR2AOKWGQ78A:3W92K5RLWVOJ4C8T91T5YJ6SEY9V5C
#                                            uniqueid  more_recent_probe  \
# 3434  A1TR2AOKWGQ78A:3W92K5RLWVOJ4C8T91T5YJ6SEY9V5C                4.0
# 3435  A1TR2AOKWGQ78A:3W92K5RLWVOJ4C8T91T5YJ6SEY9V5C                4.0
#
#       less_recent_probe  correct comparison
# 3434                6.0        0        NaN
# 3435                8.0        2        NaN
# A1UEGBZJTDJLRL:3N1FSUEFL67FEC474BA1N5U7ENK4DB
#                                            uniqueid  more_recent_probe  \
# 3468  A1UEGBZJTDJLRL:3N1FSUEFL67FEC474BA1N5U7ENK4DB                4.0
# 3469  A1UEGBZJTDJLRL:3N1FSUEFL67FEC474BA1N5U7ENK4DB                4.0
#
#       less_recent_probe  correct comparison
# 3468                6.0        1        NaN
# 3469                8.0        1        NaN
# A1UFS2BDTPT5DX:3QILPRALQ62PJPIM58EH0MM6UDHN8I
#                                            uniqueid  more_recent_probe  \
# 3502  A1UFS2BDTPT5DX:3QILPRALQ62PJPIM58EH0MM6UDHN8I                4.0
# 3503  A1UFS2BDTPT5DX:3QILPRALQ62PJPIM58EH0MM6UDHN8I                4.0
#
#       less_recent_probe  correct comparison
# 3502                6.0        2        NaN
# 3503                8.0        2        NaN
# A1UGFNSA16TKA0:34T446B1C1LOAWGSLESORWMCDVT0CX
#                                            uniqueid  more_recent_probe  \
# 3536  A1UGFNSA16TKA0:34T446B1C1LOAWGSLESORWMCDVT0CX                4.0
# 3537  A1UGFNSA16TKA0:34T446B1C1LOAWGSLESORWMCDVT0CX                4.0
#
#       less_recent_probe  correct comparison
# 3536                6.0        3        NaN
# 3537                8.0        0        NaN
# A1UH6A625GF5MD:3OSWBBLG1F46CESHOMC6KGR57QFXDP
#                                            uniqueid  more_recent_probe  \
# 3570  A1UH6A625GF5MD:3OSWBBLG1F46CESHOMC6KGR57QFXDP                4.0
# 3571  A1UH6A625GF5MD:3OSWBBLG1F46CESHOMC6KGR57QFXDP                4.0
#
#       less_recent_probe  correct comparison
# 3570                6.0        1        NaN
# 3571                8.0        2        NaN
# A1UNBT94I82S8V:30MVJZJNHNKTE4ABV2S37B006K0J9C
#                                            uniqueid  more_recent_probe  \
# 3604  A1UNBT94I82S8V:30MVJZJNHNKTE4ABV2S37B006K0J9C                4.0
# 3605  A1UNBT94I82S8V:30MVJZJNHNKTE4ABV2S37B006K0J9C                4.0
#
#       less_recent_probe  correct comparison
# 3604                6.0        2        NaN
# 3605                8.0        2        NaN
# A1UOP419O6P55R:3LWJHTCVCDTJ1151TEC4E8YXNCMFQO
#                                            uniqueid  more_recent_probe  \
# 3638  A1UOP419O6P55R:3LWJHTCVCDTJ1151TEC4E8YXNCMFQO                4.0
# 3639  A1UOP419O6P55R:3LWJHTCVCDTJ1151TEC4E8YXNCMFQO                4.0
#
#       less_recent_probe  correct comparison
# 3638                6.0        3        NaN
# 3639                8.0        3        NaN
# A1VHK9OFD7H8ZH:37QW5D2ZRHTMZ2ARD4V3ZGWCHCOS8Y
#                                            uniqueid  more_recent_probe  \
# 3672  A1VHK9OFD7H8ZH:37QW5D2ZRHTMZ2ARD4V3ZGWCHCOS8Y                4.0
# 3673  A1VHK9OFD7H8ZH:37QW5D2ZRHTMZ2ARD4V3ZGWCHCOS8Y                4.0
#
#       less_recent_probe  correct comparison
# 3672                6.0        3        NaN
# 3673                8.0        2        NaN
# A1VLH6ZN45VELT:33OOO72IVISPQ5DJJGGYB7OH9MOCTE
#                                            uniqueid  more_recent_probe  \
# 3706  A1VLH6ZN45VELT:33OOO72IVISPQ5DJJGGYB7OH9MOCTE                4.0
# 3707  A1VLH6ZN45VELT:33OOO72IVISPQ5DJJGGYB7OH9MOCTE                4.0
#
#       less_recent_probe  correct comparison
# 3706                6.0        1        NaN
# 3707                8.0        2        NaN
# A1VM6T8U5HEV0T:32KTQ2V7REMJFCGWYZ5VN3SH9TQ9MU
#                                            uniqueid  more_recent_probe  \
# 3740  A1VM6T8U5HEV0T:32KTQ2V7REMJFCGWYZ5VN3SH9TQ9MU                4.0
# 3741  A1VM6T8U5HEV0T:32KTQ2V7REMJFCGWYZ5VN3SH9TQ9MU                4.0
#
#       less_recent_probe  correct comparison
# 3740                6.0        3        NaN
# 3741                8.0        1        NaN
# A1W7T8V97ZPUH0:3TEM0PF1Q64YFOM6LANZB24UYJOD05
#                                            uniqueid  more_recent_probe  \
# 3774  A1W7T8V97ZPUH0:3TEM0PF1Q64YFOM6LANZB24UYJOD05                4.0
# 3775  A1W7T8V97ZPUH0:3TEM0PF1Q64YFOM6LANZB24UYJOD05                4.0
#
#       less_recent_probe  correct comparison
# 3774                6.0        3        NaN
# 3775                8.0        3        NaN
# A1W9J3UXKDM3DN:3F6HPJW4JE74K4PBHSW3MEMU1PV2WN
#                                            uniqueid  more_recent_probe  \
# 3808  A1W9J3UXKDM3DN:3F6HPJW4JE74K4PBHSW3MEMU1PV2WN                4.0
# 3809  A1W9J3UXKDM3DN:3F6HPJW4JE74K4PBHSW3MEMU1PV2WN                4.0
#
#       less_recent_probe  correct comparison
# 3808                6.0        0        NaN
# 3809                8.0        2        NaN
# A1WM3INNDW2776:3I7DHKZYGO7U8FM39MO1GX36Q4MF59
#                                            uniqueid  more_recent_probe  \
# 3842  A1WM3INNDW2776:3I7DHKZYGO7U8FM39MO1GX36Q4MF59                4.0
# 3843  A1WM3INNDW2776:3I7DHKZYGO7U8FM39MO1GX36Q4MF59                4.0
#
#       less_recent_probe  correct comparison
# 3842                6.0        1        NaN
# 3843                8.0        2        NaN
# A1WNL3A5Z0HQTN:3X66WABAJXPX80VU6N6QJL5YDGX3GU
#                                            uniqueid  more_recent_probe  \
# 3876  A1WNL3A5Z0HQTN:3X66WABAJXPX80VU6N6QJL5YDGX3GU                4.0
# 3877  A1WNL3A5Z0HQTN:3X66WABAJXPX80VU6N6QJL5YDGX3GU                4.0
#
#       less_recent_probe  correct comparison
# 3876                6.0        3        NaN
# 3877                8.0        3        NaN
# A1WQACYPLESVGL:3STRJBFXOXY793P7BTXWZQ1PE4WKTG
#                                            uniqueid  more_recent_probe  \
# 3910  A1WQACYPLESVGL:3STRJBFXOXY793P7BTXWZQ1PE4WKTG                4.0
# 3911  A1WQACYPLESVGL:3STRJBFXOXY793P7BTXWZQ1PE4WKTG                4.0
#
#       less_recent_probe  correct comparison
# 3910                6.0        0        NaN
# 3911                8.0        2        NaN
# A1XMGLCK09Z0DW:3R6BYFZZP8J3AY6DFS7W8GUQK36XFC
#                                            uniqueid  more_recent_probe  \
# 3944  A1XMGLCK09Z0DW:3R6BYFZZP8J3AY6DFS7W8GUQK36XFC                4.0
# 3945  A1XMGLCK09Z0DW:3R6BYFZZP8J3AY6DFS7W8GUQK36XFC                4.0
#
#       less_recent_probe  correct comparison
# 3944                6.0        3        NaN
# 3945                8.0        3        NaN
# A1XWQ3XI0GVRYG:3IO1LGZLKA4HC4CU6RS0YB0KZNT86U
#                                            uniqueid  more_recent_probe  \
# 3978  A1XWQ3XI0GVRYG:3IO1LGZLKA4HC4CU6RS0YB0KZNT86U                4.0
# 3979  A1XWQ3XI0GVRYG:3IO1LGZLKA4HC4CU6RS0YB0KZNT86U                4.0
#
#       less_recent_probe  correct comparison
# 3978                6.0        1        NaN
# 3979                8.0        2        NaN
# A1YFFIUXVE0O9W:33TIN5LC05HJ9T5AH2T6HYFOI34Y99
#                                            uniqueid  more_recent_probe  \
# 4012  A1YFFIUXVE0O9W:33TIN5LC05HJ9T5AH2T6HYFOI34Y99                4.0
# ...
# 11255                8.0        2        NaN
# AN1KXPXUDQFCQ:3IAS3U3I0GNCW1R0M107Z099RW32BD
#                                            uniqueid  more_recent_probe  \
# 11288  AN1KXPXUDQFCQ:3IAS3U3I0GNCW1R0M107Z099RW32BD                4.0
# 11289  AN1KXPXUDQFCQ:3IAS3U3I0GNCW1R0M107Z099RW32BD                4.0
#
#        less_recent_probe  correct comparison
# 11288                6.0        2        NaN
# 11289                8.0        1        NaN
# ANCTZADQC3D75:34HJIJKLP6318T4TVWAVTR0EE2EV47
#                                            uniqueid  more_recent_probe  \
# 11322  ANCTZADQC3D75:34HJIJKLP6318T4TVWAVTR0EE2EV47                4.0
# 11323  ANCTZADQC3D75:34HJIJKLP6318T4TVWAVTR0EE2EV47                4.0
#
#        less_recent_probe  correct comparison
# 11322                6.0        2        NaN
# 11323                8.0        3        NaN
# ANUA9X7BFPTR8:32SVAV9L3GGWY9IRKNEGNZUVFKQ3AM
#                                            uniqueid  more_recent_probe  \
# 11356  ANUA9X7BFPTR8:32SVAV9L3GGWY9IRKNEGNZUVFKQ3AM                4.0
# 11357  ANUA9X7BFPTR8:32SVAV9L3GGWY9IRKNEGNZUVFKQ3AM                4.0
#
#        less_recent_probe  correct comparison
# 11356                6.0        0        NaN
# 11357                8.0        0        NaN
# ANYOKF2ZV1IVA:3FUI0JHJPY5WEOJ6B8Z60RGP9A033S
#                                            uniqueid  more_recent_probe  \
# 11390  ANYOKF2ZV1IVA:3FUI0JHJPY5WEOJ6B8Z60RGP9A033S                4.0
# 11391  ANYOKF2ZV1IVA:3FUI0JHJPY5WEOJ6B8Z60RGP9A033S                4.0
#
#        less_recent_probe  correct comparison
# 11390                6.0        3        NaN
# 11391                8.0        2        NaN
# AOYDGVOZUIHII:3YDTZAI2WYNLMHOVOIQ6M3TYQZC41Z
#                                            uniqueid  more_recent_probe  \
# 11424  AOYDGVOZUIHII:3YDTZAI2WYNLMHOVOIQ6M3TYQZC41Z                4.0
# 11425  AOYDGVOZUIHII:3YDTZAI2WYNLMHOVOIQ6M3TYQZC41Z                4.0
#
#        less_recent_probe  correct comparison
# 11424                6.0        1        NaN
# 11425                8.0        0        NaN
# AP3BTOBN8Y9EJ:3WRFBPLXRBV3ISCGTRJL95EVEZGN3X
#                                            uniqueid  more_recent_probe  \
# 11458  AP3BTOBN8Y9EJ:3WRFBPLXRBV3ISCGTRJL95EVEZGN3X                4.0
# 11459  AP3BTOBN8Y9EJ:3WRFBPLXRBV3ISCGTRJL95EVEZGN3X                4.0
#
#        less_recent_probe  correct comparison
# 11458                6.0        1        NaN
# 11459                8.0        2        NaN
# AP4B1GJIT3HYF:3WT783CTPCOPUJJ2JUPDBDIV3NGCBW
#                                            uniqueid  more_recent_probe  \
# 11492  AP4B1GJIT3HYF:3WT783CTPCOPUJJ2JUPDBDIV3NGCBW                4.0
# 11493  AP4B1GJIT3HYF:3WT783CTPCOPUJJ2JUPDBDIV3NGCBW                4.0
#
#        less_recent_probe  correct comparison
# 11492                6.0        2        NaN
# 11493                8.0        2        NaN
# APD2BX78KZ5A:39RP059MEI0235VTWJJRE9N7XTSBM5
#                                           uniqueid  more_recent_probe  \
# 11526  APD2BX78KZ5A:39RP059MEI0235VTWJJRE9N7XTSBM5                4.0
# 11527  APD2BX78KZ5A:39RP059MEI0235VTWJJRE9N7XTSBM5                4.0
#
#        less_recent_probe  correct comparison
# 11526                6.0        3        NaN
# 11527                8.0        3        NaN
# APVZGZM1RA3AZ:32VNZTT0A8B9FMNCMC5LSUBBTOA4RG
#                                            uniqueid  more_recent_probe  \
# 11560  APVZGZM1RA3AZ:32VNZTT0A8B9FMNCMC5LSUBBTOA4RG                4.0
# 11561  APVZGZM1RA3AZ:32VNZTT0A8B9FMNCMC5LSUBBTOA4RG                4.0
#
#        less_recent_probe  correct comparison
# 11560                6.0        1        NaN
# 11561                8.0        2        NaN
# AQN32EZB7OQRG:3ND9UOO81L9ALQBJRYE81AL36ZHLW9
#                                            uniqueid  more_recent_probe  \
# 11594  AQN32EZB7OQRG:3ND9UOO81L9ALQBJRYE81AL36ZHLW9                4.0
# 11595  AQN32EZB7OQRG:3ND9UOO81L9ALQBJRYE81AL36ZHLW9                4.0
#
#        less_recent_probe  correct comparison
# 11594                6.0        1        NaN
# 11595                8.0        3        NaN
# AQPFTUIJ0PW2N:3HHRAGRYX9C7FF18BFK8F7HM41W9OG
#                                            uniqueid  more_recent_probe  \
# 11628  AQPFTUIJ0PW2N:3HHRAGRYX9C7FF18BFK8F7HM41W9OG                4.0
# 11629  AQPFTUIJ0PW2N:3HHRAGRYX9C7FF18BFK8F7HM41W9OG                4.0
#
#        less_recent_probe  correct comparison
# 11628                6.0        1        NaN
# 11629                8.0        2        NaN
# AQSYWZJVVMCGJ:30BUDKLTXE2221M7EB4VYFI6FFGE5O
#                                            uniqueid  more_recent_probe  \
# 11662  AQSYWZJVVMCGJ:30BUDKLTXE2221M7EB4VYFI6FFGE5O                4.0
# 11663  AQSYWZJVVMCGJ:30BUDKLTXE2221M7EB4VYFI6FFGE5O                4.0
#
#        less_recent_probe  correct comparison
# 11662                6.0        2        NaN
# 11663                8.0        1        NaN
# AR3MFFPQ39IXF:3O7L7BFSHFWEEPHMLVNPNOMBJQNEIC
#                                            uniqueid  more_recent_probe  \
# 11696  AR3MFFPQ39IXF:3O7L7BFSHFWEEPHMLVNPNOMBJQNEIC                4.0
# 11697  AR3MFFPQ39IXF:3O7L7BFSHFWEEPHMLVNPNOMBJQNEIC                4.0
#
#        less_recent_probe  correct comparison
# 11696                6.0        1        NaN
# 11697                8.0        1        NaN
# AR9AU5FY1S3RO:3N4BPTXIO9ZM9G4WBYN64MNRYTFUKG
#                                            uniqueid  more_recent_probe  \
# 11730  AR9AU5FY1S3RO:3N4BPTXIO9ZM9G4WBYN64MNRYTFUKG                4.0
# 11731  AR9AU5FY1S3RO:3N4BPTXIO9ZM9G4WBYN64MNRYTFUKG                4.0
#
#        less_recent_probe  correct comparison
# 11730                6.0        2        NaN
# 11731                8.0        1        NaN
# ARH5JQXEA02KW:31QNSG6A5S00G4QZP1XS4P0GUYD87T
#                                            uniqueid  more_recent_probe  \
# 11764  ARH5JQXEA02KW:31QNSG6A5S00G4QZP1XS4P0GUYD87T                4.0
# 11765  ARH5JQXEA02KW:31QNSG6A5S00G4QZP1XS4P0GUYD87T                4.0
#
#        less_recent_probe  correct comparison
# 11764                6.0        2        NaN
# 11765                8.0        2        NaN
# ARI1I8F8U5VMJ:3DY4FPOOA2V89Z6R68681KBO5I4RVV
#                                            uniqueid  more_recent_probe  \
# 11798  ARI1I8F8U5VMJ:3DY4FPOOA2V89Z6R68681KBO5I4RVV                4.0
# 11799  ARI1I8F8U5VMJ:3DY4FPOOA2V89Z6R68681KBO5I4RVV                4.0
#
#        less_recent_probe  correct comparison
# 11798                6.0        2        NaN
# 11799                8.0        3        NaN
# ARIWYNIH12MLF:3HMVI3QICKZ1KO2FDPED2SX5KZ71YA
#                                            uniqueid  more_recent_probe  \
# 11832  ARIWYNIH12MLF:3HMVI3QICKZ1KO2FDPED2SX5KZ71YA                4.0
# 11833  ARIWYNIH12MLF:3HMVI3QICKZ1KO2FDPED2SX5KZ71YA                4.0
#
#        less_recent_probe  correct comparison
# 11832                6.0        2        NaN
# 11833                8.0        1        NaN
# ARL0T0MU9A65G:3PS7W85Z809NS76G7W679HN939D9T2
#                                            uniqueid  more_recent_probe  \
# 11866  ARL0T0MU9A65G:3PS7W85Z809NS76G7W679HN939D9T2                4.0
# 11867  ARL0T0MU9A65G:3PS7W85Z809NS76G7W679HN939D9T2                4.0
#
#        less_recent_probe  correct comparison
# 11866                6.0        3        NaN
# 11867                8.0        2        NaN
# ARLGZWN6W91WD:30LSNF239V2MJ956SBSOLNDMMMN2IM
#                                            uniqueid  more_recent_probe  \
# 11900  ARLGZWN6W91WD:30LSNF239V2MJ956SBSOLNDMMMN2IM                4.0
# 11901  ARLGZWN6W91WD:30LSNF239V2MJ956SBSOLNDMMMN2IM                4.0
#
#        less_recent_probe  correct comparison
# 11900                6.0        2        NaN
# 11901                8.0        3        NaN
# AS55GKL261S17:3OS4RQUCRAMWXV3CAWFEJJ3Y0SHBFZ
#                                            uniqueid  more_recent_probe  \
# 11934  AS55GKL261S17:3OS4RQUCRAMWXV3CAWFEJJ3Y0SHBFZ                4.0
# 11935  AS55GKL261S17:3OS4RQUCRAMWXV3CAWFEJJ3Y0SHBFZ                4.0
#
#        less_recent_probe  correct comparison
# 11934                6.0        2        NaN
# 11935                8.0        3        NaN
# ASJ6VEA1F2APQ:3TUI152ZZCUSBMBTMFXJP6U3LQQ1Q7
#                                            uniqueid  more_recent_probe  \
# 11968  ASJ6VEA1F2APQ:3TUI152ZZCUSBMBTMFXJP6U3LQQ1Q7                4.0
# 11969  ASJ6VEA1F2APQ:3TUI152ZZCUSBMBTMFXJP6U3LQQ1Q7                4.0
#
#        less_recent_probe  correct comparison
# 11968                6.0        0        NaN
# 11969                8.0        1        NaN
# ASVBMQBG7JWP7:3C44YUNSI2W135QQ2V2PQ3525JGDPB
#                                            uniqueid  more_recent_probe  \
# 12002  ASVBMQBG7JWP7:3C44YUNSI2W135QQ2V2PQ3525JGDPB                4.0
# 12003  ASVBMQBG7JWP7:3C44YUNSI2W135QQ2V2PQ3525JGDPB                4.0
#
#        less_recent_probe  correct comparison
# 12002                6.0        3        NaN
# 12003                8.0        3        NaN
# AT80V0Q1U2LCI:3PXX5PX6LY5114M4ZGTM5IS73C4ABL
#                                            uniqueid  more_recent_probe  \
# 12036  AT80V0Q1U2LCI:3PXX5PX6LY5114M4ZGTM5IS73C4ABL                4.0
# 12037  AT80V0Q1U2LCI:3PXX5PX6LY5114M4ZGTM5IS73C4ABL                4.0
#
#        less_recent_probe  correct comparison
# 12036                6.0        2        NaN
# 12037                8.0        1        NaN
# AU4PTX44URN8D:34J10VATJG53BS7RUMIPH5BP2K8QIF
#                                            uniqueid  more_recent_probe  \
# 12070  AU4PTX44URN8D:34J10VATJG53BS7RUMIPH5BP2K8QIF                4.0
# 12071  AU4PTX44URN8D:34J10VATJG53BS7RUMIPH5BP2K8QIF                4.0
#
#        less_recent_probe  correct comparison
# 12070                6.0        2        NaN
# 12071                8.0        1        NaN
# AU6X92Y30ALJY:3JZQSN0I3RHSOCBNQI7SKUUVG56GFI
#                                            uniqueid  more_recent_probe  \
# 12104  AU6X92Y30ALJY:3JZQSN0I3RHSOCBNQI7SKUUVG56GFI                4.0
# 12105  AU6X92Y30ALJY:3JZQSN0I3RHSOCBNQI7SKUUVG56GFI                4.0
#
#        less_recent_probe  correct comparison
# 12104                6.0        1        NaN
# 12105                8.0        2        NaN
# AUMW7R5VUI5F5:39K0FND3AIMXKVQ1Q5JVJY31FB6AM8
#                                            uniqueid  more_recent_probe  \
# 12138  AUMW7R5VUI5F5:39K0FND3AIMXKVQ1Q5JVJY31FB6AM8                4.0
# 12139  AUMW7R5VUI5F5:39K0FND3AIMXKVQ1Q5JVJY31FB6AM8                4.0
#
#        less_recent_probe  correct comparison
# 12138                6.0        2        NaN
# 12139                8.0        3        NaN
# AV8T375ESPPPS:30ZX6P7VF92IEKPCATDOXOSMZTM2JS
#                                            uniqueid  more_recent_probe  \
# 12172  AV8T375ESPPPS:30ZX6P7VF92IEKPCATDOXOSMZTM2JS                4.0
# 12173  AV8T375ESPPPS:30ZX6P7VF92IEKPCATDOXOSMZTM2JS                4.0
#
#        less_recent_probe  correct comparison
# 12172                6.0        2        NaN
# 12173                8.0        1        NaN
# AVQCVKJG5OAO0:3DR23U6WE6L4N3XXF7MT1VOKV66TEA
#                                            uniqueid  more_recent_probe  \
# 12206  AVQCVKJG5OAO0:3DR23U6WE6L4N3XXF7MT1VOKV66TEA                4.0
# 12207  AVQCVKJG5OAO0:3DR23U6WE6L4N3XXF7MT1VOKV66TEA                4.0
#
#        less_recent_probe  correct comparison
# 12206                6.0        0        NaN
# 12207                8.0        2        NaN
# AVSVIOR38JDM6:3KOPY89HM997Z2LVETRTGYXE6SP3JE
#                                            uniqueid  more_recent_probe  \
# 12240  AVSVIOR38JDM6:3KOPY89HM997Z2LVETRTGYXE6SP3JE                4.0
# 12241  AVSVIOR38JDM6:3KOPY89HM997Z2LVETRTGYXE6SP3JE                4.0
#
#        less_recent_probe  correct comparison
# 12240                6.0        2        NaN
# 12241                8.0        3        NaN
# AW2UVK63OLFW:3UXUOQ9OKF4EZSJEMZH60G6BKMEA70
#                                           uniqueid  more_recent_probe  \
# 12274  AW2UVK63OLFW:3UXUOQ9OKF4EZSJEMZH60G6BKMEA70                4.0
# 12275  AW2UVK63OLFW:3UXUOQ9OKF4EZSJEMZH60G6BKMEA70                4.0
#
#        less_recent_probe  correct comparison
# 12274                6.0        0        NaN
# 12275                8.0        2        NaN
# AWJKR5GA7BS7V:3L0KT67Y8FN1E819Q8TXYTKEBZEYSM
#                                            uniqueid  more_recent_probe  \
# 12308  AWJKR5GA7BS7V:3L0KT67Y8FN1E819Q8TXYTKEBZEYSM                4.0
# 12309  AWJKR5GA7BS7V:3L0KT67Y8FN1E819Q8TXYTKEBZEYSM                4.0
#
#        less_recent_probe  correct comparison
# 12308                6.0        3        NaN
# 12309                8.0        2        NaN
# AWKJNQMK70BH3:3UJ1CZ6IZIW3CKRPF6O0NWMLFMQ5SC
#                                            uniqueid  more_recent_probe  \
# 12342  AWKJNQMK70BH3:3UJ1CZ6IZIW3CKRPF6O0NWMLFMQ5SC                4.0
# 12343  AWKJNQMK70BH3:3UJ1CZ6IZIW3CKRPF6O0NWMLFMQ5SC                4.0
#
#        less_recent_probe  correct comparison
# 12342                6.0        1        NaN
# 12343                8.0        2        NaN
# AWRY5SC68T0DC:37KGEN7NJ4XAS2TG74TKQXMRJA9PP7
#                                            uniqueid  more_recent_probe  \
# 12376  AWRY5SC68T0DC:37KGEN7NJ4XAS2TG74TKQXMRJA9PP7                4.0
# 12377  AWRY5SC68T0DC:37KGEN7NJ4XAS2TG74TKQXMRJA9PP7                4.0
#
#        less_recent_probe  correct comparison
# 12376                6.0        1        NaN
# 12377                8.0        2        NaN
# AXFCUZ1WQC2WY:3YZ8UPK3VUT4QIS8JL68G3AJS8NCUD
#                                            uniqueid  more_recent_probe  \
# 12410  AXFCUZ1WQC2WY:3YZ8UPK3VUT4QIS8JL68G3AJS8NCUD                4.0
# 12411  AXFCUZ1WQC2WY:3YZ8UPK3VUT4QIS8JL68G3AJS8NCUD                4.0
#
#        less_recent_probe  correct comparison
# 12410                6.0        2        NaN
# 12411                8.0        2        NaN
# AXFH1DT8PR0K2:31T4R4OBOTN2S7GC6DDX6BWZKXZ7CF
#                                            uniqueid  more_recent_probe  \
# 12444  AXFH1DT8PR0K2:31T4R4OBOTN2S7GC6DDX6BWZKXZ7CF                4.0
# 12445  AXFH1DT8PR0K2:31T4R4OBOTN2S7GC6DDX6BWZKXZ7CF                4.0
#
#        less_recent_probe  correct comparison
# 12444                6.0        2        NaN
# 12445                8.0        1        NaN
# AXVGIRLNPA6Z2:3R2UR8A0IBNXGBJ6EVQMVA34B4MXOM
#                                            uniqueid  more_recent_probe  \
# 12478  AXVGIRLNPA6Z2:3R2UR8A0IBNXGBJ6EVQMVA34B4MXOM                4.0
# 12479  AXVGIRLNPA6Z2:3R2UR8A0IBNXGBJ6EVQMVA34B4MXOM                4.0
#
#        less_recent_probe  correct comparison
# 12478                6.0        1        NaN
# 12479                8.0        3        NaN
# AXYNQIL0J2BP2:3M81GAB8A1QTOKTLOCQ8VI7C7UPQB7
#                                            uniqueid  more_recent_probe  \
# 12512  AXYNQIL0J2BP2:3M81GAB8A1QTOKTLOCQ8VI7C7UPQB7                4.0
# 12513  AXYNQIL0J2BP2:3M81GAB8A1QTOKTLOCQ8VI7C7UPQB7                4.0
#
#        less_recent_probe  correct comparison
# 12512                6.0        2        NaN
# 12513                8.0        2        NaN
# AY7M9MOLNXIIK:3CPLWGV3MP6PXU1WA0KV0IHHERZ9N9
#                                            uniqueid  more_recent_probe  \
# 12546  AY7M9MOLNXIIK:3CPLWGV3MP6PXU1WA0KV0IHHERZ9N9                4.0
# 12547  AY7M9MOLNXIIK:3CPLWGV3MP6PXU1WA0KV0IHHERZ9N9                4.0
#
#        less_recent_probe  correct comparison
# 12546                6.0        2        NaN
# 12547                8.0        1        NaN
# AZXNPVVLWKK1V:3RRCEFRB7NJMZF6NQFJVSF67B29B4C
#                                            uniqueid  more_recent_probe  \
# 12580  AZXNPVVLWKK1V:3RRCEFRB7NJMZF6NQFJVSF67B29B4C                4.0
# 12581  AZXNPVVLWKK1V:3RRCEFRB7NJMZF6NQFJVSF67B29B4C                4.0
#
#        less_recent_probe  correct comparison
# 12580                6.0        1        NaN
# 12581                8.0        0        NaN
# []

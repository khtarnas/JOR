# %%
from sqlalchemy import create_engine, MetaData, Table
import json
import pandas as pd

# %%
db_url = "..."
table_name = "JOR"

# %%
data_column_name = 'datastring'
# boilerplace sqlalchemy setup
engine = create_engine(db_url)
metadata = MetaData()
metadata.bind = engine
table = Table(table_name, metadata, autoload=True)
# make a query and loop through
s = table.select()

# %%
rows = s.execute()

# %% [raw]
# # Status codes
# NOT_ACCEPTED = 0
# ALLOCATED = 1
# STARTED = 2
# COMPLETED = 3
# SUBMITTED = 4
# CREDITED = 5
# QUITEARLY = 6
# BONUSED = 7

# %%
data = []
#status codes of subjects who completed experiment
statuses = [3,4,5,7]

# if you have workers you wish to exclude, add them here
exclude = ['A3NDB2NYMWE6GU:3ZOTGHDK5JIPKUX7KLKZW2MATVFOS5'] 
conditions = []
version = '2.2Confidence'

for row in rows:
    # only use subjects who completed experiment and aren't excluded
    if (row['status'] in statuses) and (row['uniqueid'] not in exclude) and (row['codeversion'] == version):
        conditions.append({
                'uniqueid': row['uniqueid'],
                'beginhit': row['beginhit'],
                'endhit': row['endhit'],
                'status': row['status'],
                'counterbalance': row['counterbalance'],
                'workerid': row['workerid'],
                'codeversion': row['codeversion']
            })
        data.append(row[data_column_name])

# %%
condition_frame = pd.DataFrame(conditions)
condition_frame.sort_values('beginhit')
# Out:
#                                          uniqueid            beginhit  \
# 17  A2U68VZTKZDB6M:3GGAI1SQEW5LDANZAJFMPTTQQGWCMY 2022-11-30 06:02:55
# 16  A2TDJIU8SZAYN8:3P529IW9KZS8A4PO1948XMZ4NOYFLA 2022-11-30 06:03:02
# 35   AWU5GS2LD252D:3MMN5BL1W0BX0ARGHQ4LWQPWK3J3MR 2022-11-30 06:03:32
# 11  A2DRJL37OEZ3B9:3QY7M81QH8TKB5S0YQUVUU9800A7KV 2022-11-30 06:08:21
# 34   AWGGLWWAXQGN0:3B1NLC6UG034FP0H4L3XWO80TDYPGG 2022-11-30 06:10:29
# 32   AL59HC7UB4RT0:3S3AMIZX3VCI9GHMXQGJ636WH24CDG 2022-11-30 06:11:31
# 0   A124AKGRZFQ8N9:39N5ACM9HFUP0FD9QFXN47MDP049PA 2022-11-30 06:13:18
# 2   A15SK40ESLQE3W:3IAS3U3I0GNCW1R0M107Z09A2QF2BQ 2022-11-30 06:13:32
# 4   A19PO2S1CDNJMQ:3PZDLQMM0USV66J601W2AKFSKBF2CX 2022-11-30 06:13:52
# 25  A36UBZG2Y7JCZO:3EKVH9QMEZB5BYPK0XRDUQXA5BR2DX 2022-11-30 06:14:01
# 15  A2SM2CGJ7W1R60:3FIJLY1B6VBY1P4MT1XFE38OSYYPFH 2022-11-30 06:14:34
# 22  A32S8F6DJQWNEW:3DL65MZB8EMN1MVMTLR3CLOHHE5CE9 2022-11-30 06:16:46
# 7   A1EYACDLY9MLIR:3RU7GD8VPP075U98ZLXEL2R3HOSPS0 2022-11-30 06:17:36
# 31   AJPB9XHN9HI8I:3PQ8K71NHYRWIUHCT2TQA782WWMAAA 2022-11-30 06:22:16
# 35     AWU5GS2LD252D:3MMN5BL1W0BX0ARGHQ4LWQPWK3J3MR
# Name: uniqueid, dtype: object

# %%
# Now we have all participant datastrings in a list.
# Let's make it a bit easier to work with:

# parse each participant's datastring as json object
# and take the 'data' sub-object
subject_data = []
for subject_json in data:
    try:
        subject_dict = json.loads(subject_json)
        subject_data.append(subject_dict['data'])
    except:
        continue

# %%
# insert uniqueid field into trialdata in case it wasn't added
# in experiment:
for part in subject_data:
    for record in part:
        record['trialdata']['uniqueid'] = record['uniqueid']

# %%
# flatten nested list so we just have a list of the trialdata recorded
# each time psiturk.recordTrialData(trialdata) was called.
trialdata = []
for part in subject_data:
    for record in part:
        trialdata.append(record['trialdata'])

# %%
# Put all subjects' trial data into a dataframe object from the
# 'pandas' python library: one option among many for analysis
data_frame = pd.DataFrame(trialdata)

# %%
#data_frame[data_frame['subj_wrote_words'].notnull()][100:150]
data_frame[data_frame['uniqueid'] == 'A3MYPYBVHX7FQ2']
# Out:
# Empty DataFrame
# Columns: [rt, responses, type, trial_type, trial_index, time_elapsed, internal_node_id, uniqueid, stimulus, key_press, button_pressed, block_number, left_word_study, right_word_study, trial_period, left_word_test, right_word_test, chosen_side, comparison_type, left_comp_type, right_comp_type, correct_side, subj_wrote_words]
# Index: []
#
# [0 rows x 23 columns]

# %%
# Print how many subj before eliminations:
len(data_frame['uniqueid'].unique())
# Out:
# 461

# %%
# Remove subjects that admitted to writing down studied words
said_yes_count = 0
for i in data_frame[data_frame['subj_wrote_words'] == 'yes']['uniqueid'].unique():
    said_yes_count += 1
    data_frame = data_frame.drop(data_frame[data_frame['uniqueid'] == i].index)
said_yes_count
# Out:
# 198

# %%
# Print how many subj after eliminations
len(data_frame['uniqueid'].unique())
# Out:
# 263

# %%
data_frame_2 = data_frame
# %store data_frame_2
# Out:
# Stored 'data_frame_2' (DataFrame)

# %%
data_frame_2
# Out:
#              rt                  responses  type              trial_type  \
# 474     10746.9  {"name":"A107RJSS561Y7R"}  NAME        survey-html-form
# 475      3416.7                        NaN   NaN  html-keyboard-response
# 476     24256.2                        NaN   NaN    html-button-response
# 477      1533.3                        NaN   NaN    html-button-response
# 478     19102.0                        NaN   NaN  html-keyboard-response
# ...         ...                        ...   ...                     ...
# 110570      NaN                        NaN   NaN  html-keyboard-response
# 110571  31697.0                        NaN   NaN  html-keyboard-response
# 110572      NaN                        NaN   NaN  html-keyboard-response
# 110573   4322.0                        NaN   NaN  html-keyboard-response
# 110574  19875.0                        NaN   NaN    html-button-response
#
#         trial_index  time_elapsed internal_node_id  \
# 474               0         10750      0.0-0.0-0.0
# 475               1         14373          0.0-1.0
# 476               2         38844      0.0-2.0-0.0
# 477               3         40379      0.0-2.0-1.0
# 478               4         59483          0.0-3.0
# ...             ...           ...              ...
# 110570          232       1434857        0.0-223.0
# 110571          233       1467313        0.0-224.0
# 110572          234       1472071        0.0-225.0
# 110573          235       1477153        0.0-226.0
# 110574          236       1497788        0.0-227.0
#
#                                              uniqueid  \
# 474     A107RJSS561Y7R:3I2PTA7R3U1UHNXFUP31ULQ0R9IKQ4
# 475     A107RJSS561Y7R:3I2PTA7R3U1UHNXFUP31ULQ0R9IKQ4
# 476     A107RJSS561Y7R:3I2PTA7R3U1UHNXFUP31ULQ0R9IKQ4
# 477     A107RJSS561Y7R:3I2PTA7R3U1UHNXFUP31ULQ0R9IKQ4
# 478     A107RJSS561Y7R:3I2PTA7R3U1UHNXFUP31ULQ0R9IKQ4
# ...                                               ...
# 110570   AZUW6B4UIG0RL:38JBBYETQPHK6II706LLTNCQBD64EA
# 110571   AZUW6B4UIG0RL:38JBBYETQPHK6II706LLTNCQBD64EA
# 110572   AZUW6B4UIG0RL:38JBBYETQPHK6II706LLTNCQBD64EA
# 110573   AZUW6B4UIG0RL:38JBBYETQPHK6II706LLTNCQBD64EA
# 110574   AZUW6B4UIG0RL:38JBBYETQPHK6II706LLTNCQBD64EA
#
#                                                  stimulus key_press  ...  \
# 474                                                   NaN       NaN  ...
# 475     Welcome to the <strong>Judgment of Recency</st...            ...
# 476     <p class='inst-justified'>According to Wikiped...       NaN  ...
# 477     <p class='inst'>How often do you realize you'v...       NaN  ...
# 478     <p>In this experiment, you will encounter a nu...            ...
# ...                                                   ...       ...  ...
# 110570  <h1 style="font-size: 35px">COTTAGE</h1><h1 st...      None  ...
# 110571  <h1 style="font-size: 35px;">LUNCH<span style=...         Z  ...
# 110572  <h1 style="font-size: 35px">PERFUME</h1><h1 st...      None  ...
# 110573  <h1 style="font-size: 35px;">SANDWICH<span sty...         Z  ...
# 110574  <p>Congratulations on finishing the experiment...       NaN  ...
#
#        right_word_study  trial_period left_word_test right_word_test  \
# 474                 NaN           NaN            NaN             NaN
# 475                 NaN           NaN            NaN             NaN
# 476                 NaN           NaN            NaN             NaN
# 477                 NaN           NaN            NaN             NaN
# 478                 NaN           NaN            NaN             NaN
# ...                 ...           ...            ...             ...
# 110570           PASTRY         study            NaN             NaN
# 110571              NaN          test          LUNCH           STOVE
# 110572             RUST         study            NaN             NaN
# 110573              NaN          test       SANDWICH         GRIZZLY
# 110574              NaN           NaN            NaN             NaN
#
#        chosen_side comparison_type left_comp_type  right_comp_type  \
# 474            NaN             NaN            NaN              NaN
# 475            NaN             NaN            NaN              NaN
# 476            NaN             NaN            NaN              NaN
# 477            NaN             NaN            NaN              NaN
# 478            NaN             NaN            NaN              NaN
# ...            ...             ...            ...              ...
# 110570         NaN             NaN            NaN              NaN
# 110571         0.0         [6, 34]            6.0             34.0
# 110572         NaN             NaN            NaN              NaN
# 110573         0.0        [34, 40]           34.0             40.0
# 110574         NaN             NaN            NaN              NaN
#
#        correct_side  subj_wrote_words
# 474             NaN               NaN
# 475             NaN               NaN
# 476             NaN               NaN
# 477             NaN               NaN
# 478             NaN               NaN
# ...             ...               ...
# 110570          NaN               NaN
# 110571          0.0               NaN
# 110572          NaN               NaN
# 110573          0.0               NaN
# 110574          NaN                no
#
# [62974 rows x 23 columns]
